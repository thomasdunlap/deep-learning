# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count / total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = random.randint(1, window_size + 1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx + 1: stop + 1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 3
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/3 Iteration: 100 Avg. Training loss: 5.6355 0.8653 sec/batch
# Epoch 1/3 Iteration: 200 Avg. Training loss: 5.6291 0.8548 sec/batch
# Epoch 1/3 Iteration: 300 Avg. Training loss: 5.5192 1.0473 sec/batch
# Epoch 1/3 Iteration: 400 Avg. Training loss: 5.6403 0.9188 sec/batch
# Epoch 1/3 Iteration: 500 Avg. Training loss: 5.4878 1.0434 sec/batch
# Epoch 1/3 Iteration: 600 Avg. Training loss: 5.5503 1.4891 sec/batch
# Epoch 1/3 Iteration: 700 Avg. Training loss: 5.5582 1.3277 sec/batch
# Epoch 1/3 Iteration: 800 Avg. Training loss: 5.5389 1.1088 sec/batch
# Epoch 1/3 Iteration: 900 Avg. Training loss: 5.4141 0.8981 sec/batch
# Epoch 1/3 Iteration: 1000 Avg. Training loss: 5.4400 0.8277 sec/batch
# Nearest to and: glasgow, stays, biennial, gandhi, bucks, flamboyant, interlisp, loud,
# Nearest to years: portent, yeomen, hawar, edc, otp, rana, insertions, stories,
# Nearest to united: approximation, unsuspecting, coarse, turin, fringing, conformation, brezhnev, altenburg,
# Nearest to used: they, spoofed, adware, internationalized, burdens, resistance, irresistible, alex,
# Nearest to where: cladograms, atlas, dab, hired, emerson, manas, parcels, daytona,
# Nearest to the: gia, esquivel, rendered, unrefined, cellular, banca, kylie, counter,
# Nearest to however: monophosphate, xxix, guide, toontown, nikaya, markham, wallpaper, atop,
# Nearest to first: romain, generalizing, dynastic, arminianism, contradicted, drama, wrigley, odos,
# Nearest to operating: blockading, revoked, cassava, semiconductors, pharaonic, revelation, covalent, mcnelly,
# Nearest to police: tata, predestined, trachea, pleasant, playford, edif, heijenoort, unattractive,
# Nearest to smith: boxcar, lobbied, journeys, fantasyland, firewall, impressive, szombathely, aykroyd,
# Nearest to except: coaxial, waleed, teos, zombie, gaborone, repetitive, microfibrils, cavalli,
# Nearest to notes: ccta, asl, olives, diena, interpretations, allied, austen, hh,
# Nearest to stage: pohnpei, exemplify, immunization, wimax, redbrick, bookstore, injecting, willard,
# Nearest to writers: sociale, renderman, capricious, eftpos, ml, mistook, bigelow, beer,
# Nearest to instance: seward, ignores, macworld, epidemiological, sorensen, strategically, inaudible, cosa,
# Epoch 1/3 Iteration: 1100 Avg. Training loss: 5.4865 0.8430 sec/batch
# Epoch 1/3 Iteration: 1200 Avg. Training loss: 5.3552 0.8258 sec/batch
# Epoch 1/3 Iteration: 1300 Avg. Training loss: 5.3379 0.9045 sec/batch
# Epoch 1/3 Iteration: 1400 Avg. Training loss: 5.2098 1.0963 sec/batch
# Epoch 1/3 Iteration: 1500 Avg. Training loss: 5.1674 0.8393 sec/batch
# Epoch 1/3 Iteration: 1600 Avg. Training loss: 5.1206 0.7861 sec/batch
# Epoch 1/3 Iteration: 1700 Avg. Training loss: 5.0643 0.7786 sec/batch
# Epoch 1/3 Iteration: 1800 Avg. Training loss: 5.0523 0.7812 sec/batch
# Epoch 1/3 Iteration: 1900 Avg. Training loss: 4.9875 0.8627 sec/batch
# Epoch 1/3 Iteration: 2000 Avg. Training loss: 4.9562 1.0689 sec/batch
# Nearest to and: glasgow, stays, household, yes, designates, delivering, biennial, loud,
# Nearest to years: stories, plays, loss, should, styles, yeomen, someone, lucas,
# Nearest to united: approximation, coarse, federal, unsuspecting, saturday, simplicity, truths, turin,
# Nearest to used: they, ratified, rounded, expectancy, resistance, alex, spoofed, crafts,
# Nearest to where: cladograms, dab, atlas, hired, together, buying, couples, howl,
# Nearest to the: rendered, significance, germany, unrefined, gia, greatly, cellular, esquivel,
# Nearest to however: guide, monophosphate, may, perceptions, xxix, help, drink, trunk,
# Nearest to first: drama, romain, generalizing, dynastic, reconstruct, contradicted, classes, profits,
# Nearest to operating: revoked, cassava, blockading, offense, semiconductors, sephardic, depriving, revelation,
# Nearest to police: tata, pleasant, millennium, guile, millennia, unattractive, kurt, trachea,
# Nearest to smith: journeys, impressive, times, lobbied, boxcar, criminal, offering, fantasyland,
# Nearest to except: coaxial, relatively, microfibrils, repetitive, basis, cavalli, comfortably, zombie,
# Nearest to notes: ccta, allied, interpretations, asl, progression, cf, olives, carmelites,
# Nearest to stage: pohnpei, exemplify, wimax, grinch, allegorically, immunization, amounts, bookstore,
# Nearest to writers: sociale, mistook, bigelow, renderman, ml, capricious, bard, eftpos,
# Nearest to instance: ignores, cooperation, epidemiological, patterns, fresh, knight, mib, macworld,
# Epoch 1/3 Iteration: 2100 Avg. Training loss: 4.9073 1.0558 sec/batch
# Epoch 1/3 Iteration: 2200 Avg. Training loss: 4.8660 0.9569 sec/batch
# Epoch 1/3 Iteration: 2300 Avg. Training loss: 4.8620 0.9453 sec/batch
# Epoch 1/3 Iteration: 2400 Avg. Training loss: 4.8574 0.8622 sec/batch
# Epoch 1/3 Iteration: 2500 Avg. Training loss: 4.8223 0.8666 sec/batch
# Epoch 1/3 Iteration: 2600 Avg. Training loss: 4.8256 0.7706 sec/batch
# Epoch 1/3 Iteration: 2700 Avg. Training loss: 4.8247 0.7691 sec/batch
# Epoch 1/3 Iteration: 2800 Avg. Training loss: 4.7897 0.7667 sec/batch
# Epoch 1/3 Iteration: 2900 Avg. Training loss: 4.7923 0.7701 sec/batch
# Epoch 1/3 Iteration: 3000 Avg. Training loss: 4.7832 1.2705 sec/batch
# Nearest to and: stays, glasgow, loud, yes, designates, delivering, biennial, umbrella,
# Nearest to years: stories, lucas, yeomen, clients, portent, styles, identities, psammetichus,
# Nearest to united: approximation, coarse, federal, simplicity, turin, drowning, unsuspecting, saturday,
# Nearest to used: they, burdens, spoofed, adware, sr, rounded, internationalized, expectancy,
# Nearest to where: hired, cladograms, atlas, prizes, dab, protest, engaging, buying,
# Nearest to the: rendered, coast, germany, significance, unrefined, greatly, esquivel, advice,
# Nearest to however: monophosphate, guide, guatemala, trunk, xxix, multiplication, may, atop,
# Nearest to first: romain, generalizing, contradicted, dynastic, reconstruct, drama, federated, concurrently,
# Nearest to operating: revoked, cassava, semiconductors, blockading, offense, revelation, covalent, christina,
# Nearest to police: tata, pleasant, kurt, unattractive, millennia, guile, neglected, repetitions,
# Nearest to smith: journeys, impressive, lobbied, boxcar, times, fantasyland, ipcc, firewall,
# Nearest to except: coaxial, repetitive, relatively, microfibrils, cavalli, counts, pdas, zombie,
# Nearest to notes: allied, ccta, interpretations, progression, cf, asl, carmelites, olives,
# Nearest to stage: pohnpei, exemplify, wimax, injecting, allegorically, grinch, redbrick, immunization,
# Nearest to writers: sociale, mistook, capricious, closing, renderman, ml, bigelow, palestrina,
# Nearest to instance: ignores, cooperation, knight, patterns, gbc, mib, strategically, epidemiological,
# Epoch 1/3 Iteration: 3100 Avg. Training loss: 4.7622 1.1983 sec/batch
# Epoch 1/3 Iteration: 3200 Avg. Training loss: 4.7631 1.0893 sec/batch
# Epoch 1/3 Iteration: 3300 Avg. Training loss: 4.7193 0.7783 sec/batch
# Epoch 1/3 Iteration: 3400 Avg. Training loss: 4.6991 0.7699 sec/batch
# Epoch 1/3 Iteration: 3500 Avg. Training loss: 4.7549 0.7738 sec/batch
# Epoch 1/3 Iteration: 3600 Avg. Training loss: 4.6948 0.7715 sec/batch
# Epoch 1/3 Iteration: 3700 Avg. Training loss: 4.7026 0.7697 sec/batch
# Epoch 1/3 Iteration: 3800 Avg. Training loss: 4.7450 0.7699 sec/batch
# Epoch 1/3 Iteration: 3900 Avg. Training loss: 4.6928 0.7669 sec/batch
# Epoch 1/3 Iteration: 4000 Avg. Training loss: 4.6515 0.7672 sec/batch
# Nearest to and: stays, glasgow, implantation, biennial, yes, loud, ratification, gandhi,
# Nearest to years: portent, yeomen, psammetichus, expectancy, mortality, partement, lucas, incapacitation,
# Nearest to united: federal, coarse, approximation, unsuspecting, brezhnev, moran, wesley, occured,
# Nearest to used: they, burdens, spoofed, adware, irresistible, sr, internationalized, can,
# Nearest to where: hired, cladograms, atlas, emerson, dab, parcels, prizes, velar,
# Nearest to the: rendered, coast, arab, germany, unrefined, significance, esquivel, federative,
# Nearest to however: monophosphate, trunk, guide, guatemala, rediscovery, vignettes, xxix, melbourne,
# Nearest to first: romain, generalizing, drama, reconstruct, contradicted, terrorists, dynastic, odos,
# Nearest to operating: revoked, blockading, semiconductors, cassava, revelation, creeks, covalent, offense,
# Nearest to police: tata, pleasant, kurt, heijenoort, interglacial, predestined, barbarous, repetitions,
# Nearest to smith: impressive, journeys, lobbied, boxcar, mahatma, fern, fantasyland, times,
# Nearest to except: coaxial, cavalli, repetitive, waleed, counts, basis, microfibrils, nans,
# Nearest to notes: ccta, allied, interpretations, asl, diena, progression, cf, olives,
# Nearest to stage: pohnpei, exemplify, wimax, injecting, willard, allegorically, remove, redbrick,
# Nearest to writers: sociale, ml, closing, capricious, renderman, mistook, bigelow, facts,
# Nearest to instance: ignores, cooperation, epidemiological, gbc, knight, mib, patterns, cosa,
# Epoch 1/3 Iteration: 4100 Avg. Training loss: 4.6629 0.7726 sec/batch
# Epoch 1/3 Iteration: 4200 Avg. Training loss: 4.6733 0.7709 sec/batch
# Epoch 1/3 Iteration: 4300 Avg. Training loss: 4.6241 0.7734 sec/batch
# Epoch 1/3 Iteration: 4400 Avg. Training loss: 4.6375 0.7720 sec/batch
# Epoch 1/3 Iteration: 4500 Avg. Training loss: 4.6382 0.7679 sec/batch
# Epoch 1/3 Iteration: 4600 Avg. Training loss: 4.6103 0.8465 sec/batch
# Epoch 2/3 Iteration: 4700 Avg. Training loss: 4.6238 0.5536 sec/batch
# Epoch 2/3 Iteration: 4800 Avg. Training loss: 4.5500 0.7679 sec/batch
# Epoch 2/3 Iteration: 4900 Avg. Training loss: 4.5170 0.7808 sec/batch
# Epoch 2/3 Iteration: 5000 Avg. Training loss: 4.4917 0.7717 sec/batch
# Nearest to and: stays, implantation, glasgow, eunuchs, delivering, yes, loud, biennial,
# Nearest to years: mortality, expectancy, portent, psammetichus, yeomen, incapacitation, sued, yunnan,
# Nearest to united: federal, coarse, wesley, unsuspecting, moran, chunky, montreal, tolbert,
# Nearest to used: they, burdens, can, spoofed, adware, irresistible, machines, internationalized,
# Nearest to where: hired, cladograms, parcels, chaotic, engaging, daytona, velar, dab,
# Nearest to the: rendered, coast, arab, unrefined, significance, federative, esquivel, germany,
# Nearest to however: monophosphate, trunk, nikaya, wallpaper, rediscovery, sedentary, vignettes, xxix,
# Nearest to first: romain, generalizing, contradicted, drama, odos, concurrently, reconstruct, terrorists,
# Nearest to operating: revoked, blockading, semiconductors, offense, chupacabras, creeks, cassava, bowden,
# Nearest to police: tata, pleasant, kurt, heijenoort, barbarous, interglacial, unattractive, predestined,
# Nearest to smith: journeys, boxcar, impressive, lobbied, mahatma, fern, fantasyland, trespass,
# Nearest to except: coaxial, cavalli, waleed, basis, counts, teos, microfibrils, repetitive,
# Nearest to notes: asl, ccta, allied, interpretations, olives, diena, progression, carmelites,
# Nearest to stage: pohnpei, exemplify, wimax, injecting, redbrick, grinch, brains, bookstore,
# Nearest to writers: sociale, renderman, capricious, closing, facts, ml, mistook, chili,
# Nearest to instance: ignores, epidemiological, patterns, gbc, mib, cosa, cooperation, dismisses,
# Epoch 2/3 Iteration: 5100 Avg. Training loss: 4.4774 0.7745 sec/batch
# Epoch 2/3 Iteration: 5200 Avg. Training loss: 4.5064 0.7713 sec/batch
# Epoch 2/3 Iteration: 5300 Avg. Training loss: 4.4517 0.7715 sec/batch
# Epoch 2/3 Iteration: 5400 Avg. Training loss: 4.5157 0.7650 sec/batch
# Epoch 2/3 Iteration: 5500 Avg. Training loss: 4.4894 0.8148 sec/batch
# Epoch 2/3 Iteration: 5600 Avg. Training loss: 4.4876 1.0456 sec/batch
# Epoch 2/3 Iteration: 5700 Avg. Training loss: 4.4517 0.9040 sec/batch
# Epoch 2/3 Iteration: 5800 Avg. Training loss: 4.4036 0.8958 sec/batch
# Epoch 2/3 Iteration: 5900 Avg. Training loss: 4.4495 0.9420 sec/batch
# Epoch 2/3 Iteration: 6000 Avg. Training loss: 4.4132 0.9355 sec/batch
# Nearest to and: stays, implantation, yes, delivering, ranges, nested, eunuchs, grouped,
# Nearest to years: mortality, expectancy, female, yunnan, portent, psychologically, sued, partement,
# Nearest to united: federal, chunky, military, unsuspecting, moran, wesley, coarse, brezhnev,
# Nearest to used: they, can, adware, burdens, spoofed, machines, irresistible, interaction,
# Nearest to where: hired, cladograms, chaotic, parcels, daytona, engaging, ancients, sexist,
# Nearest to the: coast, rendered, unrefined, arab, campanile, esquivel, significance, rossini,
# Nearest to however: monophosphate, nikaya, wallpaper, sedentary, rediscovery, trunk, help, vignettes,
# Nearest to first: generalizing, romain, contradicted, drama, hjalmar, odos, reconstruct, wrigley,
# Nearest to operating: revoked, blockading, bowden, creeks, chupacabras, workbench, available, semiconductors,
# Nearest to police: tata, heijenoort, pleasant, predestined, barbarous, interglacial, unattractive, kurt,
# Nearest to smith: journeys, boxcar, mahatma, impressive, fern, lobbied, fantasyland, trespass,
# Nearest to except: coaxial, waleed, teos, counts, basis, cavalli, repetitive, itinerarium,
# Nearest to notes: asl, ccta, olives, prefixed, carmelites, progression, finkelstein, allied,
# Nearest to stage: pohnpei, exemplify, wimax, brains, redbrick, injecting, humours, immunization,
# Nearest to writers: sociale, renderman, facts, capricious, closing, chili, philologie, fremantle,
# Nearest to instance: ignores, epidemiological, patterns, cosa, gbc, dismisses, mib, cooperation,
# Epoch 2/3 Iteration: 6100 Avg. Training loss: 4.4628 0.9172 sec/batch
# Epoch 2/3 Iteration: 6200 Avg. Training loss: 4.4005 0.9412 sec/batch
# Epoch 2/3 Iteration: 6300 Avg. Training loss: 4.4530 0.8549 sec/batch
# Epoch 2/3 Iteration: 6400 Avg. Training loss: 4.4190 0.8001 sec/batch
# Epoch 2/3 Iteration: 6500 Avg. Training loss: 4.4104 0.9089 sec/batch
# Epoch 2/3 Iteration: 6600 Avg. Training loss: 4.4442 0.9292 sec/batch
# Epoch 2/3 Iteration: 6700 Avg. Training loss: 4.4166 1.0678 sec/batch
# Epoch 2/3 Iteration: 6800 Avg. Training loss: 4.3860 0.9517 sec/batch
# Epoch 2/3 Iteration: 6900 Avg. Training loss: 4.4266 0.8821 sec/batch
# Epoch 2/3 Iteration: 7000 Avg. Training loss: 4.3807 0.8646 sec/batch
# Nearest to and: stays, implantation, nested, yes, grouped, biennial, umbrella, killebrew,
# Nearest to years: expectancy, mortality, female, yunnan, psammetichus, partement, portent, male,
# Nearest to united: federal, military, wesley, chunky, unsuspecting, brezhnev, moran, ancien,
# Nearest to used: they, spoofed, adware, burdens, plural, irresistible, can, machines,
# Nearest to where: hired, cladograms, parcels, chaotic, together, emerson, daytona, abbr,
# Nearest to the: unrefined, rendered, cyclical, coast, arab, significance, quadriceps, stand,
# Nearest to however: monophosphate, may, sedentary, help, trunk, nikaya, vum, xxix,
# Nearest to first: drama, romain, contradicted, generalizing, hjalmar, odos, reconstruct, ipt,
# Nearest to operating: revoked, blockading, disk, browser, available, creeks, chupacabras, bowden,
# Nearest to police: tata, pleasant, heijenoort, predestined, sheltering, unattractive, barbarous, kurt,
# Nearest to smith: journeys, boxcar, fantasyland, fern, mahatma, monday, beau, lobbied,
# Nearest to except: coaxial, waleed, basis, teos, repetitive, counts, cavalli, relatively,
# Nearest to notes: asl, ccta, prefixed, olives, progression, finkelstein, interpretations, carmelites,
# Nearest to stage: pohnpei, wimax, exemplify, redbrick, humours, grinch, injecting, immunization,
# Nearest to writers: renderman, sociale, facts, capricious, philologie, closing, estudios, cinema,
# Nearest to instance: ignores, epidemiological, gbc, inaudible, patterns, cosa, mib, cooperation,
# Epoch 2/3 Iteration: 7100 Avg. Training loss: 4.3858 1.0400 sec/batch
# Epoch 2/3 Iteration: 7200 Avg. Training loss: 4.3741 1.3138 sec/batch
# Epoch 2/3 Iteration: 7300 Avg. Training loss: 4.3664 1.4103 sec/batch
# Epoch 2/3 Iteration: 7400 Avg. Training loss: 4.3662 1.4094 sec/batch
# Epoch 2/3 Iteration: 7500 Avg. Training loss: 4.3650 1.4500 sec/batch
# Epoch 2/3 Iteration: 7600 Avg. Training loss: 4.3706 1.6359 sec/batch
# Epoch 2/3 Iteration: 7700 Avg. Training loss: 4.4070 0.9281 sec/batch
# Epoch 2/3 Iteration: 7800 Avg. Training loss: 4.3806 0.8381 sec/batch
# Epoch 2/3 Iteration: 7900 Avg. Training loss: 4.3474 0.8256 sec/batch
# Epoch 2/3 Iteration: 8000 Avg. Training loss: 4.3584 0.7675 sec/batch
# Nearest to and: implantation, stays, nested, biennial, grouped, nourishment, killebrew, thirdly,
# Nearest to years: expectancy, mortality, female, male, yunnan, migrant, portent, psammetichus,
# Nearest to united: federal, military, brezhnev, wesley, overseas, unsuspecting, chunky, interim,
# Nearest to used: adware, they, burdens, spoofed, plural, pc, irresistible, can,
# Nearest to where: hired, cladograms, parcels, chaotic, daytona, staccato, subluxation, velar,
# Nearest to the: unrefined, arab, rendered, cyclical, coast, of, federative, mutable,
# Nearest to however: monophosphate, sedentary, iranian, vum, guatemala, may, xxix, kriol,
# Nearest to first: romain, drama, contradicted, generalizing, odos, reconstruct, hjalmar, ipt,
# Nearest to operating: revoked, browser, disk, workbench, blockading, floppy, chupacabras, available,
# Nearest to police: tata, sheltering, pleasant, predestined, interglacial, heijenoort, knockout, appointed,
# Nearest to smith: journeys, boxcar, fantasyland, fern, mahatma, monday, beau, woodbridge,
# Nearest to except: waleed, coaxial, teos, chalcedon, counts, cavalli, brokerage, basis,
# Nearest to notes: asl, prefixed, ccta, progression, cf, finkelstein, nuke, hh,
# Nearest to stage: exemplify, pohnpei, wimax, redbrick, humours, injecting, immunization, brains,
# Nearest to writers: renderman, sociale, capricious, facts, philologie, cinema, baptize, estudios,
# Nearest to instance: ignores, inaudible, gbc, cosa, epidemiological, patterns, dismisses, geostationary,
# Epoch 2/3 Iteration: 8100 Avg. Training loss: 4.3516 0.7847 sec/batch
# Epoch 2/3 Iteration: 8200 Avg. Training loss: 4.3005 0.7996 sec/batch
# Epoch 2/3 Iteration: 8300 Avg. Training loss: 4.3794 0.7786 sec/batch
# Epoch 2/3 Iteration: 8400 Avg. Training loss: 4.3815 0.7727 sec/batch
# Epoch 2/3 Iteration: 8500 Avg. Training loss: 4.3858 0.7696 sec/batch
# Epoch 2/3 Iteration: 8600 Avg. Training loss: 4.2985 0.7710 sec/batch
# Epoch 2/3 Iteration: 8700 Avg. Training loss: 4.3101 0.7644 sec/batch
# Epoch 2/3 Iteration: 8800 Avg. Training loss: 4.3204 0.7736 sec/batch
# Epoch 2/3 Iteration: 8900 Avg. Training loss: 4.2425 0.7734 sec/batch
# Epoch 2/3 Iteration: 9000 Avg. Training loss: 4.2866 0.7741 sec/batch
# Nearest to and: implantation, biennial, stays, grouped, fringed, bharat, glasgow, commoner,
# Nearest to years: expectancy, mortality, female, male, migrant, yunnan, infant, deaths,
# Nearest to united: federal, military, brezhnev, wesley, chunky, overseas, unsuspecting, militia,
# Nearest to used: adware, spoofed, burdens, they, irresistible, plural, rounded, can,
# Nearest to where: hired, parcels, cladograms, daytona, along, emerson, staccato, chaotic,
# Nearest to the: cyclical, coast, stand, unrefined, of, in, a, rendered,
# Nearest to however: monophosphate, sedentary, iranian, vum, contention, may, nikaya, rediscovery,
# Nearest to first: romain, drama, contradicted, generalizing, hjalmar, odos, concurrently, reconstruct,
# Nearest to operating: revoked, browser, gui, workbench, chupacabras, blockading, disk, available,
# Nearest to police: tata, sheltering, appointed, predestined, heijenoort, financial, pleasant, knockout,
# Nearest to smith: fantasyland, boxcar, journeys, fern, woodbridge, mahatma, beau, automating,
# Nearest to except: waleed, teos, chalcedon, coaxial, candlemas, brokerage, cavalli, completed,
# Nearest to notes: asl, ccta, prefixed, cf, finkelstein, interpretations, progression, mullis,
# Nearest to stage: wimax, pohnpei, exemplify, redbrick, humours, injecting, jozef, willard,
# Nearest to writers: renderman, philologie, facts, sociale, capricious, cinema, estudios, manly,
# Nearest to instance: ignores, inaudible, gbc, cosa, patterns, epidemiological, dismisses, geostationary,
# Epoch 2/3 Iteration: 9100 Avg. Training loss: 4.2930 1.0603 sec/batch
# Epoch 2/3 Iteration: 9200 Avg. Training loss: 4.3148 0.8490 sec/batch
# Epoch 3/3 Iteration: 9300 Avg. Training loss: 4.3284 0.3481 sec/batch
# Epoch 3/3 Iteration: 9400 Avg. Training loss: 4.2767 0.7867 sec/batch
# Epoch 3/3 Iteration: 9500 Avg. Training loss: 4.2421 0.7898 sec/batch
# Epoch 3/3 Iteration: 9600 Avg. Training loss: 4.2471 0.7961 sec/batch
# Epoch 3/3 Iteration: 9700 Avg. Training loss: 4.2284 0.7876 sec/batch
# Epoch 3/3 Iteration: 9800 Avg. Training loss: 4.2071 0.7895 sec/batch
# Epoch 3/3 Iteration: 9900 Avg. Training loss: 4.2529 0.7899 sec/batch
# Epoch 3/3 Iteration: 10000 Avg. Training loss: 4.1829 1.2401 sec/batch
# Nearest to and: ranges, implantation, bestowing, fringed, grouped, spezia, bharat, stays,
# Nearest to years: expectancy, mortality, female, male, migrant, yunnan, infant, deaths,
# Nearest to united: federal, military, wesley, brezhnev, chunky, unsuspecting, overseas, law,
# Nearest to used: adware, spoofed, they, plural, irresistible, burdens, supercharger, paired,
# Nearest to where: hired, parcels, cladograms, along, sexist, staccato, subluxation, daytona,
# Nearest to the: cyclical, coast, of, a, stand, bundling, campanile, in,
# Nearest to however: monophosphate, sedentary, nikaya, contention, iranian, vum, wallpaper, help,
# Nearest to first: romain, contradicted, drama, generalizing, hjalmar, odos, reconstruct, ohio,
# Nearest to operating: revoked, workbench, gui, browser, chupacabras, screen, capabilities, floppy,
# Nearest to police: tata, sheltering, appointed, predestined, knockout, abused, heijenoort, interrogators,
# Nearest to smith: fantasyland, boxcar, woodbridge, journeys, fern, beau, mahatma, achaemenids,
# Nearest to except: teos, waleed, coaxial, chalcedon, itinerarium, nans, counts, candlemas,
# Nearest to notes: asl, ccta, prefixed, finkelstein, cf, progression, mullis, newsgroups,
# Nearest to stage: wimax, pohnpei, redbrick, exemplify, humours, injecting, brains, immunization,
# Nearest to writers: renderman, philologie, facts, sociale, capricious, cinema, language, estudios,
# Nearest to instance: ignores, cosa, inaudible, patterns, geostationary, gbc, epidemiological, determinism,
# Epoch 3/3 Iteration: 10100 Avg. Training loss: 4.2532 0.7999 sec/batch
# Epoch 3/3 Iteration: 10200 Avg. Training loss: 4.2177 0.7820 sec/batch
# Epoch 3/3 Iteration: 10300 Avg. Training loss: 4.2157 0.7802 sec/batch
# Epoch 3/3 Iteration: 10400 Avg. Training loss: 4.1505 0.7800 sec/batch
# Epoch 3/3 Iteration: 10500 Avg. Training loss: 4.1897 0.7795 sec/batch
# Epoch 3/3 Iteration: 10600 Avg. Training loss: 4.1786 0.8090 sec/batch
# Epoch 3/3 Iteration: 10700 Avg. Training loss: 4.1420 0.8406 sec/batch
# Epoch 3/3 Iteration: 10800 Avg. Training loss: 4.1926 0.7828 sec/batch
# Epoch 3/3 Iteration: 10900 Avg. Training loss: 4.2010 0.7818 sec/batch
# Epoch 3/3 Iteration: 11000 Avg. Training loss: 4.1675 0.7781 sec/batch
# Nearest to and: spezia, implantation, biennial, airspeeds, bestowing, ranges, nested, refutable,
# Nearest to years: expectancy, mortality, female, male, migrant, yunnan, deaths, psammetichus,
# Nearest to united: federal, military, wesley, chunky, brezhnev, law, unsuspecting, coven,
# Nearest to used: adware, spoofed, plural, they, burdens, supercharger, paired, creamy,
# Nearest to where: hired, parcels, along, cladograms, delta, cdot, staccato, protest,
# Nearest to the: of, stand, cyclical, a, campanile, significance, in, rendered,
# Nearest to however: monophosphate, nikaya, sedentary, round, contention, iranian, vum, neutrinos,
# Nearest to first: drama, romain, contradicted, generalizing, hjalmar, reconstruct, classes, second,
# Nearest to operating: revoked, workbench, browser, chupacabras, gui, screen, capabilities, floppy,
# Nearest to police: tata, sheltering, appointed, heijenoort, abused, predestined, knockout, interrogators,
# Nearest to smith: fantasyland, boxcar, fern, woodbridge, journeys, brubeck, clown, achaemenids,
# Nearest to except: coaxial, waleed, teos, chalcedon, counts, nans, itinerarium, relatively,
# Nearest to notes: asl, ccta, prefixed, finkelstein, cf, progression, mullis, improvisations,
# Nearest to stage: wimax, pohnpei, exemplify, redbrick, humours, injecting, brains, reflectivity,
# Nearest to writers: philologie, renderman, sociale, facts, capricious, cinema, estudios, language,
# Nearest to instance: ignores, cosa, inaudible, patterns, y, step, unceasing, determinism,
# Epoch 3/3 Iteration: 11100 Avg. Training loss: 4.2000 0.7930 sec/batch
# Epoch 3/3 Iteration: 11200 Avg. Training loss: 4.2579 0.8072 sec/batch
# Epoch 3/3 Iteration: 11300 Avg. Training loss: 4.1916 0.7814 sec/batch
# Epoch 3/3 Iteration: 11400 Avg. Training loss: 4.1646 0.7832 sec/batch
# Epoch 3/3 Iteration: 11500 Avg. Training loss: 4.1892 1.4365 sec/batch
# Epoch 3/3 Iteration: 11600 Avg. Training loss: 4.2322 0.8213 sec/batch
# Epoch 3/3 Iteration: 11700 Avg. Training loss: 4.2014 1.0535 sec/batch
# Epoch 3/3 Iteration: 11800 Avg. Training loss: 4.1826 0.7882 sec/batch
# Epoch 3/3 Iteration: 11900 Avg. Training loss: 4.1557 0.7821 sec/batch
# Epoch 3/3 Iteration: 12000 Avg. Training loss: 4.1782 0.7781 sec/batch
# Nearest to and: biennial, spezia, nourishment, glasgow, bestowing, airspeeds, refutable, implantation,
# Nearest to years: expectancy, mortality, female, male, migrant, deaths, infant, yunnan,
# Nearest to united: federal, military, wesley, law, brezhnev, overseas, states, chunky,
# Nearest to used: adware, spoofed, plural, burdens, labiodental, supercharger, giza, gradually,
# Nearest to where: hired, cdot, delta, along, parcels, daytona, topological, cladograms,
# Nearest to the: of, a, cyclical, significance, in, assembleia, first, stand,
# Nearest to however: monophosphate, sedentary, nikaya, iranian, xxix, machining, round, guatemala,
# Nearest to first: drama, romain, contradicted, generalizing, reconstruct, the, ipt, classes,
# Nearest to operating: revoked, workbench, chupacabras, gui, browser, screen, capabilities, floppy,
# Nearest to police: tata, sheltering, abused, appointed, heijenoort, knockout, predestined, fbi,
# Nearest to smith: fantasyland, fern, boxcar, woodbridge, brubeck, clown, journeys, mes,
# Nearest to except: chalcedon, counts, coaxial, teos, nans, candlemas, midianites, elicits,
# Nearest to notes: asl, prefixed, ccta, newsgroups, progression, cf, finkelstein, mullis,
# Nearest to stage: wimax, redbrick, pohnpei, exemplify, humours, injecting, brains, grinch,
# Nearest to writers: philologie, renderman, capricious, facts, sociale, cinema, estudios, manly,
# Nearest to instance: ignores, cosa, sorensen, inaudible, y, unceasing, gbc, patterns,
# Epoch 3/3 Iteration: 12100 Avg. Training loss: 4.2132 0.7867 sec/batch
# Epoch 3/3 Iteration: 12200 Avg. Training loss: 4.1657 0.7842 sec/batch
# Epoch 3/3 Iteration: 12300 Avg. Training loss: 4.1788 0.7771 sec/batch
# Epoch 3/3 Iteration: 12400 Avg. Training loss: 4.1973 0.7803 sec/batch
# Epoch 3/3 Iteration: 12500 Avg. Training loss: 4.1533 0.9654 sec/batch
# Epoch 3/3 Iteration: 12600 Avg. Training loss: 4.1543 1.1568 sec/batch
# Epoch 3/3 Iteration: 12700 Avg. Training loss: 4.1636 1.0573 sec/batch
# Epoch 3/3 Iteration: 12800 Avg. Training loss: 4.1461 1.0338 sec/batch
# Epoch 3/3 Iteration: 12900 Avg. Training loss: 4.1867 1.0275 sec/batch
# Epoch 3/3 Iteration: 13000 Avg. Training loss: 4.1978 1.2083 sec/batch
# Nearest to and: biennial, wrestler, turgot, obe, fringed, worker, for, geologist,
# Nearest to years: expectancy, mortality, female, male, migrant, deaths, infant, yunnan,
# Nearest to united: federal, wesley, military, states, brezhnev, vietnam, bolton, law,
# Nearest to used: adware, spoofed, plural, giza, burdens, irresistible, labiodental, ke,
# Nearest to where: hired, parcels, delta, along, cdot, protest, daytona, homophone,
# Nearest to the: of, in, a, first, stand, sabatini, magistracy, officially,
# Nearest to however: monophosphate, iranian, xxix, vum, may, sedentary, nikaya, contention,
# Nearest to first: the, romain, drama, contradicted, second, ohio, hjalmar, turbulent,
# Nearest to operating: revoked, workbench, gui, chupacabras, browser, capabilities, screen, floppy,
# Nearest to police: tata, sheltering, abused, interrogators, appointed, heijenoort, fbi, knockout,
# Nearest to smith: fantasyland, woodbridge, boxcar, fern, brubeck, clown, aykroyd, mes,
# Nearest to except: chalcedon, counts, midianites, waleed, candlemas, teos, veto, nans,
# Nearest to notes: asl, prefixed, ccta, newsgroups, progression, cf, finkelstein, improvisations,
# Nearest to stage: pohnpei, wimax, redbrick, exemplify, humours, emerson, injecting, brains,
# Nearest to writers: philologie, capricious, renderman, facts, belknap, cinema, sociale, estudios,
# Nearest to instance: ignores, cosa, sorensen, unceasing, geostationary, gbc, epidemiological, scharnhorst,
# Epoch 3/3 Iteration: 13100 Avg. Training loss: 4.2496 1.2998 sec/batch
# Epoch 3/3 Iteration: 13200 Avg. Training loss: 4.1495 1.0523 sec/batch
# Epoch 3/3 Iteration: 13300 Avg. Training loss: 4.1195 0.7985 sec/batch
# Epoch 3/3 Iteration: 13400 Avg. Training loss: 4.1728 0.7949 sec/batch
# Epoch 3/3 Iteration: 13500 Avg. Training loss: 4.0547 0.8198 sec/batch
# Epoch 3/3 Iteration: 13600 Avg. Training loss: 4.1636 0.8670 sec/batch
# Epoch 3/3 Iteration: 13700 Avg. Training loss: 4.1881 0.7757 sec/batch
# Epoch 3/3 Iteration: 13800 Avg. Training loss: 4.1369 0.8370 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
