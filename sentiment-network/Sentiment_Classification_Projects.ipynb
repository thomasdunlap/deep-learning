# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    
    if labels[i] == 'POSITIVE':
        for word in reviews[i].split(' '):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(' '):
            negative_counts[word] += 1
            total_counts[word] += 1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 1651404),
#  ('the', 519972),
#  ('.', 478962),
#  ('and', 269166),
#  ('a', 251064),
#  ('of', 230565),
#  ('to', 200238),
#  ('is', 171735),
#  ('in', 150645),
#  ('br', 147705),
#  ('it', 144075),
#  ('i', 122229),
#  ('that', 106890),
#  ('this', 105240),
#  ('s', 101445),
#  ('as', 78924),
#  ('with', 69741),
#  ('for', 67248),
#  ('was', 65751),
#  ('film', 62811),
#  ('but', 62466),
#  ('movie', 57222),
#  ('his', 51681),
#  ('on', 51024),
#  ('you', 50043),
#  ('he', 48846),
#  ('are', 44421),
#  ('not', 42816),
#  ('t', 41160),
#  ('one', 40965),
#  ('have', 37761),
#  ('be', 37248),
#  ('by', 35991),
#  ('all', 35826),
#  ('who', 34392),
#  ('an', 33882),
#  ('at', 33702),
#  ('from', 32301),
#  ('her', 31422),
#  ('they', 29685),
#  ('has', 27558),
#  ('so', 27462),
#  ('like', 27114),
#  ('about', 24939),
#  ('very', 24915),
#  ('out', 24402),
#  ('there', 24171),
#  ('she', 23337),
#  ('what', 23211),
#  ('or', 23196),
#  ('good', 23160),
#  ('more', 22563),
#  ('when', 22368),
#  ('some', 22323),
#  ('if', 21855),
#  ('just', 21456),
#  ('can', 21003),
#  ('story', 20340),
#  ('time', 19545),
#  ('my', 19464),
#  ('great', 19257),
#  ('well', 19215),
#  ('up', 18963),
#  ('which', 18801),
#  ('their', 18321),
#  ('see', 18078),
#  ('also', 16650),
#  ('we', 16593),
#  ('really', 16428),
#  ('would', 16200),
#  ('will', 15654),
#  ('me', 15501),
#  ('had', 15444),
#  ('only', 15411),
#  ('him', 15054),
#  ('even', 14892),
#  ('most', 14592),
#  ('other', 14574),
#  ('were', 14346),
#  ('first', 14265),
#  ('than', 14208),
#  ('much', 14055),
#  ('its', 13866),
#  ('no', 13722),
#  ('into', 13632),
#  ('people', 13437),
#  ('best', 12957),
#  ('love', 12903),
#  ('get', 12816),
#  ('how', 12639),
#  ('life', 12597),
#  ('been', 12567),
#  ('because', 12237),
#  ('way', 12108),
#  ('do', 11823),
#  ('made', 11469),
#  ('films', 11439),
#  ('them', 11415),
#  ('after', 11400),
#  ('many', 11298),
#  ('two', 11199),
#  ('too', 10977),
#  ('think', 10965),
#  ('movies', 10758),
#  ('characters', 10680),
#  ('character', 10542),
#  ('don', 10404),
#  ('man', 10380),
#  ('show', 10296),
#  ('watch', 10272),
#  ('seen', 10242),
#  ('then', 10074),
#  ('little', 10023),
#  ('still', 10020),
#  ('make', 9909),
#  ('could', 9711),
#  ('never', 9678),
#  ('being', 9651),
#  ('where', 9519),
#  ('does', 9207),
#  ('over', 9051),
#  ('any', 9006),
#  ('while', 8697),
#  ('know', 8499),
#  ('did', 8370),
#  ('years', 8274),
#  ('here', 8220),
#  ('ever', 8202),
#  ('end', 8088),
#  ('these', 8082),
#  ('such', 7770),
#  ('real', 7704),
#  ('scene', 7701),
#  ('back', 7641),
#  ('those', 7455),
#  ('though', 7425),
#  ('off', 7389),
#  ('new', 7374),
#  ('your', 7359),
#  ('go', 7320),
#  ('acting', 7311),
#  ('plot', 7296),
#  ('world', 7287),
#  ('scenes', 7281),
#  ('say', 7242),
#  ('through', 7227),
#  ('makes', 7170),
#  ('better', 7143),
#  ('now', 7104),
#  ('work', 7038),
#  ('young', 7029),
#  ('old', 6933),
#  ('ve', 6921),
#  ('find', 6816),
#  ('both', 6744),
#  ('before', 6531),
#  ('us', 6486),
#  ('again', 6474),
#  ('series', 6459),
#  ('quite', 6429),
#  ('something', 6405),
#  ('cast', 6399),
#  ('should', 6363),
#  ('part', 6294),
#  ('always', 6264),
#  ('lot', 6261),
#  ('another', 6225),
#  ('actors', 6141),
#  ('director', 6120),
#  ('family', 6096),
#  ('between', 6048),
#  ('own', 6048),
#  ('m', 5994),
#  ('may', 5991),
#  ('same', 5916),
#  ('role', 5901),
#  ('watching', 5898),
#  ('every', 5862),
#  ('funny', 5859),
#  ('doesn', 5805),
#  ('performance', 5784),
#  ('few', 5754),
#  ('bad', 5721),
#  ('look', 5700),
#  ('re', 5652),
#  ('why', 5565),
#  ('things', 5547),
#  ('times', 5496),
#  ('big', 5445),
#  ('however', 5385),
#  ('actually', 5370),
#  ('action', 5367),
#  ('going', 5349),
#  ('bit', 5271),
#  ('comedy', 5226),
#  ('down', 5220),
#  ('music', 5214),
#  ('must', 5184),
#  ('take', 5127),
#  ('saw', 5076),
#  ('long', 5070),
#  ('right', 5064),
#  ('fun', 5058),
#  ('fact', 5052),
#  ('excellent', 5049),
#  ('around', 5022),
#  ('didn', 5016),
#  ('without', 5013),
#  ('thing', 4986),
#  ('thought', 4917),
#  ('got', 4905),
#  ('each', 4890),
#  ('day', 4842),
#  ('feel', 4791),
#  ('seems', 4788),
#  ('come', 4782),
#  ('done', 4758),
#  ('beautiful', 4740),
#  ('especially', 4716),
#  ('played', 4713),
#  ('almost', 4698),
#  ('want', 4686),
#  ('yet', 4668),
#  ('give', 4659),
#  ('pretty', 4647),
#  ('last', 4629),
#  ('since', 4557),
#  ('different', 4512),
#  ('although', 4503),
#  ('gets', 4470),
#  ('true', 4461),
#  ('interesting', 4443),
#  ('job', 4410),
#  ('enough', 4365),
#  ('our', 4362),
#  ('shows', 4341),
#  ('horror', 4323),
#  ('woman', 4317),
#  ('tv', 4200),
#  ('probably', 4194),
#  ('father', 4185),
#  ('original', 4179),
#  ('girl', 4170),
#  ('point', 4137),
#  ('plays', 4134),
#  ('wonderful', 4116),
#  ('far', 4074),
#  ('course', 4074),
#  ('john', 4050),
#  ('rather', 4020),
#  ('isn', 3984),
#  ('ll', 3978),
#  ('later', 3972),
#  ('dvd', 3972),
#  ('whole', 3930),
#  ('war', 3930),
#  ('d', 3921),
#  ('found', 3918),
#  ('away', 3918),
#  ('screen', 3915),
#  ('nothing', 3900),
#  ('year', 3891),
#  ('once', 3888),
#  ('hard', 3882),
#  ('together', 3840),
#  ('set', 3831),
#  ('am', 3831),
#  ('having', 3798),
#  ('making', 3795),
#  ('place', 3789),
#  ('might', 3780),
#  ('comes', 3780),
#  ('sure', 3759),
#  ('american', 3744),
#  ('play', 3735),
#  ('kind', 3732),
#  ('perfect', 3726),
#  ('takes', 3726),
#  ('performances', 3711),
#  ('himself', 3690),
#  ('worth', 3663),
#  ('everyone', 3663),
#  ('anyone', 3642),
#  ('actor', 3609),
#  ('three', 3603),
#  ('wife', 3588),
#  ('classic', 3576),
#  ('goes', 3558),
#  ('ending', 3534),
#  ('version', 3504),
#  ('star', 3447),
#  ('enjoy', 3438),
#  ('book', 3426),
#  ('nice', 3396),
#  ('everything', 3384),
#  ('during', 3372),
#  ('put', 3354),
#  ('seeing', 3333),
#  ('least', 3306),
#  ('house', 3300),
#  ('high', 3285),
#  ('watched', 3282),
#  ('loved', 3261),
#  ('men', 3261),
#  ('night', 3246),
#  ('anything', 3225),
#  ('believe', 3213),
#  ('guy', 3213),
#  ('top', 3189),
#  ('amazing', 3174),
#  ('hollywood', 3168),
#  ('looking', 3159),
#  ('main', 3132),
#  ('definitely', 3129),
#  ('gives', 3093),
#  ('home', 3087),
#  ('seem', 3084),
#  ('episode', 3069),
#  ('audience', 3060),
#  ('sense', 3060),
#  ('truly', 3051),
#  ('special', 3033),
#  ('second', 3027),
#  ('short', 3027),
#  ('fan', 3027),
#  ('mind', 3015),
#  ('human', 3003),
#  ('recommend', 2997),
#  ('full', 2988),
#  ('black', 2985),
#  ('help', 2973),
#  ('along', 2967),
#  ('trying', 2961),
#  ('small', 2958),
#  ('death', 2955),
#  ('friends', 2943),
#  ('remember', 2922),
#  ('often', 2910),
#  ('said', 2898),
#  ('favorite', 2886),
#  ('heart', 2877),
#  ('early', 2871),
#  ('left', 2868),
#  ('until', 2865),
#  ('script', 2862),
#  ('let', 2862),
#  ('maybe', 2811),
#  ('today', 2808),
#  ('live', 2802),
#  ('less', 2802),
#  ('moments', 2799),
#  ('others', 2787),
#  ('brilliant', 2778),
#  ('shot', 2775),
#  ('liked', 2769),
#  ('become', 2748),
#  ('won', 2745),
#  ('used', 2730),
#  ('style', 2721),
#  ('mother', 2685),
#  ('lives', 2682),
#  ('came', 2679),
#  ('stars', 2670),
#  ('cinema', 2667),
#  ('looks', 2655),
#  ('perhaps', 2652),
#  ('read', 2646),
#  ('enjoyed', 2637),
#  ('boy', 2625),
#  ('drama', 2619),
#  ('highly', 2613),
#  ('given', 2610),
#  ('playing', 2601),
#  ('use', 2592),
#  ('next', 2577),
#  ('women', 2574),
#  ('fine', 2571),
#  ('effects', 2568),
#  ('kids', 2562),
#  ('entertaining', 2559),
#  ('need', 2556),
#  ('line', 2550),
#  ('works', 2544),
#  ('someone', 2541),
#  ('mr', 2508),
#  ('simply', 2505),
#  ('picture', 2499),
#  ('children', 2499),
#  ('face', 2493),
#  ('keep', 2493),
#  ('friend', 2493),
#  ('dark', 2490),
#  ('overall', 2484),
#  ('certainly', 2484),
#  ('minutes', 2481),
#  ('wasn', 2472),
#  ('history', 2466),
#  ('finally', 2460),
#  ('couple', 2448),
#  ('against', 2445),
#  ('son', 2427),
#  ('understand', 2424),
#  ('lost', 2421),
#  ('michael', 2415),
#  ('else', 2403),
#  ('throughout', 2394),
#  ('fans', 2391),
#  ('city', 2376),
#  ('reason', 2367),
#  ('written', 2361),
#  ('production', 2361),
#  ('several', 2352),
#  ('school', 2349),
#  ('based', 2343),
#  ('rest', 2343),
#  ('try', 2340),
#  ('dead', 2328),
#  ('hope', 2325),
#  ('strong', 2304),
#  ('white', 2295),
#  ('tell', 2277),
#  ('itself', 2274),
#  ('half', 2259),
#  ('person', 2247),
#  ('sometimes', 2238),
#  ('past', 2232),
#  ('start', 2232),
#  ('genre', 2229),
#  ('beginning', 2217),
#  ('final', 2217),
#  ('town', 2214),
#  ('art', 2202),
#  ('humor', 2196),
#  ('game', 2196),
#  ('yes', 2193),
#  ('idea', 2193),
#  ('late', 2190),
#  ('becomes', 2187),
#  ('despite', 2187),
#  ('able', 2178),
#  ('case', 2178),
#  ('money', 2169),
#  ('child', 2163),
#  ('completely', 2163),
#  ('side', 2157),
#  ('camera', 2148),
#  ('getting', 2142),
#  ('instead', 2136),
#  ('soon', 2106),
#  ('under', 2100),
#  ('viewer', 2097),
#  ('age', 2091),
#  ('days', 2088),
#  ('stories', 2088),
#  ('felt', 2082),
#  ('simple', 2082),
#  ('roles', 2079),
#  ('video', 2064),
#  ('name', 2049),
#  ('either', 2049),
#  ('doing', 2031),
#  ('turns', 2022),
#  ('wants', 2013),
#  ('close', 2013),
#  ('title', 2007),
#  ('wrong', 2004),
#  ('went', 1998),
#  ('james', 1995),
#  ('evil', 1977),
#  ('budget', 1971),
#  ('episodes', 1971),
#  ('relationship', 1965),
#  ('fantastic', 1959),
#  ('piece', 1959),
#  ('david', 1953),
#  ('turn', 1944),
#  ('murder', 1938),
#  ('parts', 1935),
#  ('brother', 1932),
#  ('absolutely', 1929),
#  ('head', 1929),
#  ('experience', 1926),
#  ('eyes', 1923),
#  ('sex', 1914),
#  ('direction', 1911),
#  ('called', 1911),
#  ('directed', 1908),
#  ('lines', 1902),
#  ('behind', 1899),
#  ('sort', 1896),
#  ('actress', 1893),
#  ('lead', 1890),
#  ('oscar', 1884),
#  ('including', 1881),
#  ('example', 1881),
#  ('known', 1875),
#  ('musical', 1875),
#  ('chance', 1863),
#  ('score', 1860),
#  ('already', 1857),
#  ('feeling', 1857),
#  ('hit', 1857),
#  ('voice', 1845),
#  ('moment', 1836),
#  ('living', 1836),
#  ('low', 1830),
#  ('supporting', 1830),
#  ('ago', 1827),
#  ('themselves', 1824),
#  ('reality', 1815),
#  ('hilarious', 1815),
#  ('jack', 1812),
#  ('told', 1809),
#  ('hand', 1803),
#  ('quality', 1800),
#  ('moving', 1800),
#  ('dialogue', 1800),
#  ('song', 1797),
#  ('happy', 1797),
#  ('matter', 1794),
#  ('paul', 1794),
#  ('light', 1782),
#  ('future', 1779),
#  ('entire', 1776),
#  ('finds', 1773),
#  ('gave', 1767),
#  ('laugh', 1761),
#  ('released', 1758),
#  ('expect', 1752),
#  ('fight', 1743),
#  ('particularly', 1740),
#  ('cinematography', 1737),
#  ('police', 1737),
#  ('whose', 1734),
#  ('type', 1734),
#  ('sound', 1734),
#  ('view', 1719),
#  ('enjoyable', 1719),
#  ('number', 1716),
#  ('romantic', 1716),
#  ('husband', 1716),
#  ('daughter', 1716),
#  ('documentary', 1713),
#  ('self', 1710),
#  ('superb', 1707),
#  ('modern', 1707),
#  ('took', 1707),
#  ('robert', 1707),
#  ('mean', 1698),
#  ('shown', 1689),
#  ('coming', 1683),
#  ('important', 1680),
#  ('king', 1677),
#  ('leave', 1677),
#  ('change', 1674),
#  ('somewhat', 1665),
#  ('wanted', 1665),
#  ('tells', 1662),
#  ('events', 1656),
#  ('run', 1656),
#  ('career', 1656),
#  ('country', 1656),
#  ('heard', 1650),
#  ('season', 1650),
#  ('greatest', 1647),
#  ('girls', 1647),
#  ('etc', 1641),
#  ('care', 1638),
#  ('starts', 1635),
#  ('english', 1626),
#  ('killer', 1623),
#  ('tale', 1620),
#  ('guys', 1620),
#  ('totally', 1620),
#  ('animation', 1620),
#  ('usual', 1617),
#  ('miss', 1605),
#  ('opinion', 1605),
#  ('easy', 1593),
#  ('violence', 1593),
#  ('songs', 1590),
#  ('british', 1584),
#  ('says', 1578),
#  ('realistic', 1575),
#  ('writing', 1572),
#  ('writer', 1566),
#  ('act', 1566),
#  ('comic', 1563),
#  ('thriller', 1557),
#  ('television', 1551),
#  ('power', 1548),
#  ('ones', 1545),
#  ('kid', 1542),
#  ('york', 1539),
#  ('novel', 1539),
#  ('alone', 1536),
#  ('problem', 1536),
#  ('attention', 1527),
#  ('involved', 1524),
#  ('kill', 1521),
#  ('extremely', 1521),
#  ('seemed', 1518),
#  ('hero', 1515),
#  ('french', 1515),
#  ('rock', 1512),
#  ('stuff', 1503),
#  ('wish', 1497),
#  ('begins', 1494),
#  ('taken', 1491),
#  ('sad', 1491),
#  ('ways', 1488),
#  ('richard', 1485),
#  ('knows', 1482),
#  ('atmosphere', 1479),
#  ('similar', 1473),
#  ('surprised', 1473),
#  ('taking', 1473),
#  ('car', 1473),
#  ('george', 1470),
#  ('perfectly', 1470),
#  ('across', 1467),
#  ('team', 1467),
#  ('eye', 1467),
#  ('sequence', 1467),
#  ('room', 1464),
#  ('due', 1464),
#  ('among', 1464),
#  ('serious', 1464),
#  ('powerful', 1464),
#  ('strange', 1461),
#  ('order', 1461),
#  ('cannot', 1461),
#  ('b', 1461),
#  ('beauty', 1458),
#  ('famous', 1455),
#  ('happened', 1452),
#  ('tries', 1452),
#  ('herself', 1452),
#  ('myself', 1452),
#  ('class', 1449),
#  ('four', 1446),
#  ('cool', 1443),
#  ('release', 1437),
#  ('anyway', 1437),
#  ('theme', 1437),
#  ('opening', 1434),
#  ('entertainment', 1431),
#  ('slow', 1425),
#  ('ends', 1425),
#  ('unique', 1425),
#  ('exactly', 1425),
#  ('easily', 1422),
#  ('level', 1422),
#  ('o', 1422),
#  ('red', 1422),
#  ('interest', 1416),
#  ('happen', 1413),
#  ('crime', 1410),
#  ('viewing', 1404),
#  ('sets', 1401),
#  ('memorable', 1401),
#  ('stop', 1398),
#  ('group', 1398),
#  ('problems', 1389),
#  ('dance', 1389),
#  ('working', 1389),
#  ('sister', 1389),
#  ('message', 1389),
#  ('knew', 1386),
#  ('mystery', 1383),
#  ('nature', 1383),
#  ('bring', 1380),
#  ('believable', 1377),
#  ('thinking', 1377),
#  ('brought', 1377),
#  ('mostly', 1374),
#  ('disney', 1371),
#  ('couldn', 1371),
#  ('society', 1368),
#  ('lady', 1365),
#  ('within', 1365),
#  ('blood', 1362),
#  ('parents', 1359),
#  ('upon', 1359),
#  ('viewers', 1359),
#  ('meets', 1356),
#  ('form', 1356),
#  ('peter', 1356),
#  ('tom', 1356),
#  ('usually', 1356),
#  ('soundtrack', 1356),
#  ('local', 1350),
#  ('certain', 1344),
#  ('follow', 1344),
#  ('whether', 1341),
#  ('possible', 1338),
#  ('emotional', 1335),
#  ('killed', 1332),
#  ('above', 1332),
#  ('de', 1332),
#  ('god', 1329),
#  ('middle', 1329),
#  ('needs', 1326),
#  ('happens', 1326),
#  ('flick', 1326),
#  ('masterpiece', 1323),
#  ('period', 1320),
#  ('major', 1320),
#  ('named', 1317),
#  ('haven', 1317),
#  ('particular', 1314),
#  ('th', 1314),
#  ('earth', 1311),
#  ('feature', 1311),
#  ('stand', 1308),
#  ('words', 1305),
#  ('typical', 1305),
#  ('elements', 1299),
#  ('obviously', 1299),
#  ('romance', 1293),
#  ('jane', 1290),
#  ('yourself', 1281),
#  ('showing', 1281),
#  ('brings', 1278),
#  ('fantasy', 1278),
#  ('guess', 1269),
#  ('america', 1269),
#  ('unfortunately', 1266),
#  ('huge', 1266),
#  ('indeed', 1263),
#  ('running', 1263),
#  ('talent', 1260),
#  ('stage', 1257),
#  ('started', 1254),
#  ('leads', 1251),
#  ('sweet', 1251),
#  ('japanese', 1251),
#  ('poor', 1248),
#  ('deal', 1248),
#  ('incredible', 1239),
#  ('personal', 1239),
#  ('fast', 1236),
#  ('became', 1230),
#  ('deep', 1230),
#  ('hours', 1227),
#  ('giving', 1224),
#  ('nearly', 1224),
#  ('dream', 1224),
#  ('clearly', 1221),
#  ('turned', 1221),
#  ('obvious', 1218),
#  ('near', 1218),
#  ('cut', 1215),
#  ('surprise', 1215),
#  ('era', 1212),
#  ('body', 1212),
#  ('hour', 1209),
#  ('female', 1209),
#  ('five', 1209),
#  ('note', 1197),
#  ('learn', 1194),
#  ('truth', 1194),
#  ('except', 1191),
#  ('feels', 1191),
#  ('match', 1191),
#  ('tony', 1191),
#  ('filmed', 1182),
#  ('clear', 1182),
#  ('complete', 1182),
#  ('street', 1179),
#  ('eventually', 1179),
#  ('keeps', 1179),
#  ('older', 1179),
#  ('lots', 1179),
#  ('buy', 1176),
#  ('william', 1173),
#  ('stewart', 1173),
#  ('fall', 1170),
#  ('joe', 1170),
#  ('meet', 1170),
#  ('unlike', 1167),
#  ('talking', 1167),
#  ('shots', 1167),
#  ('rating', 1167),
#  ('difficult', 1167),
#  ('dramatic', 1164),
#  ('means', 1164),
#  ('situation', 1158),
#  ('wonder', 1158),
#  ('present', 1158),
#  ('appears', 1158),
#  ('subject', 1158),
#  ('comments', 1155),
#  ('general', 1149),
#  ('sequences', 1149),
#  ('lee', 1149),
#  ('points', 1146),
#  ('earlier', 1146),
#  ('gone', 1137),
#  ('check', 1137),
#  ('suspense', 1134),
#  ('recommended', 1134),
#  ('ten', 1134),
#  ('third', 1131),
#  ('business', 1131),
#  ('talk', 1125),
#  ('leaves', 1125),
#  ('beyond', 1125),
#  ('portrayal', 1122),
#  ('beautifully', 1119),
#  ('single', 1116),
#  ('bill', 1116),
#  ('plenty', 1113),
#  ('word', 1113),
#  ('whom', 1110),
#  ('falls', 1110),
#  ('scary', 1107),
#  ('non', 1107),
#  ('figure', 1107),
#  ('battle', 1107),
#  ('using', 1104),
#  ('return', 1104),
#  ('doubt', 1101),
#  ('add', 1101),
#  ('hear', 1098),
#  ('solid', 1098),
#  ('success', 1098),
#  ('jokes', 1095),
#  ('oh', 1095),
#  ('touching', 1095),
#  ('political', 1095),
#  ('hell', 1092),
#  ('awesome', 1092),
#  ('boys', 1092),
#  ('sexual', 1086),
#  ('recently', 1086),
#  ('dog', 1086),
#  ('please', 1083),
#  ('wouldn', 1083),
#  ('straight', 1083),
#  ('features', 1083),
#  ('forget', 1080),
#  ('setting', 1080),
#  ('lack', 1080),
#  ('married', 1077),
#  ('mark', 1077),
#  ('social', 1071),
#  ('interested', 1068),
#  ('adventure', 1068),
#  ('actual', 1065),
#  ('terrific', 1065),
#  ('sees', 1065),
#  ('brothers', 1065),
#  ('move', 1062),
#  ('call', 1062),
#  ('various', 1059),
#  ('theater', 1059),
#  ('dr', 1059),
#  ('animated', 1056),
#  ('western', 1053),
#  ('baby', 1050),
#  ('space', 1050),
#  ('leading', 1044),
#  ('disappointed', 1044),
#  ('portrayed', 1038),
#  ('aren', 1038),
#  ('screenplay', 1035),
#  ('smith', 1035),
#  ('towards', 1032),
#  ('hate', 1032),
#  ('noir', 1029),
#  ('outstanding', 1026),
#  ('decent', 1026),
#  ('kelly', 1026),
#  ('directors', 1023),
#  ('journey', 1023),
#  ('none', 1020),
#  ('looked', 1020),
#  ('effective', 1020),
#  ('storyline', 1017),
#  ('caught', 1017),
#  ('sci', 1017),
#  ('fi', 1017),
#  ('cold', 1017),
#  ('mary', 1017),
#  ('rich', 1014),
#  ('charming', 1014),
#  ('popular', 1011),
#  ('rare', 1011),
#  ('manages', 1011),
#  ('harry', 1011),
#  ('spirit', 1008),
#  ('appreciate', 1005),
#  ('open', 1005),
#  ('moves', 1002),
#  ('basically', 1002),
#  ('acted', 1002),
#  ('inside', 999),
#  ('boring', 999),
#  ('century', 999),
#  ('mention', 999),
#  ('deserves', 999),
#  ('subtle', 999),
#  ('pace', 999),
#  ('familiar', 996),
#  ('background', 996),
#  ('ben', 993),
#  ('creepy', 990),
#  ('supposed', 990),
#  ('secret', 987),
#  ('die', 984),
#  ('jim', 984),
#  ('question', 981),
#  ('effect', 981),
#  ('natural', 981),
#  ('impressive', 978),
#  ('rate', 978),
#  ('language', 978),
#  ('saying', 975),
#  ('intelligent', 975),
#  ('telling', 972),
#  ('realize', 972),
#  ('material', 972),
#  ('scott', 972),
#  ('singing', 969),
#  ('dancing', 966),
#  ('visual', 963),
#  ('adult', 963),
#  ('imagine', 963),
#  ('kept', 960),
#  ('office', 960),
#  ('uses', 957),
#  ('pure', 954),
#  ('wait', 954),
#  ('stunning', 954),
#  ('review', 951),
#  ('previous', 951),
#  ('copy', 951),
#  ('seriously', 951),
#  ('reading', 948),
#  ('create', 948),
#  ('hot', 948),
#  ('created', 948),
#  ('magic', 948),
#  ('somehow', 948),
#  ('stay', 945),
#  ('attempt', 945),
#  ('escape', 945),
#  ('crazy', 945),
#  ('air', 945),
#  ('frank', 945),
#  ('hands', 942),
#  ('filled', 939),
#  ('expected', 936),
#  ('average', 936),
#  ('surprisingly', 936),
#  ('complex', 933),
#  ('quickly', 930),
#  ('successful', 930),
#  ('studio', 930),
#  ('plus', 927),
#  ('male', 927),
#  ('co', 921),
#  ('images', 918),
#  ('casting', 918),
#  ('following', 918),
#  ('minute', 918),
#  ('exciting', 918),
#  ('members', 915),
#  ('follows', 915),
#  ('themes', 915),
#  ('german', 915),
#  ('reasons', 915),
#  ('e', 915),
#  ('touch', 912),
#  ('edge', 912),
#  ('free', 912),
#  ('cute', 912),
#  ('genius', 912),
#  ('outside', 909),
#  ('reviews', 906),
#  ('admit', 906),
#  ('ok', 906),
#  ('younger', 906),
#  ('fighting', 903),
#  ('odd', 903),
#  ('master', 903),
#  ('recent', 900),
#  ('thanks', 900),
#  ('break', 900),
#  ('comment', 900),
#  ('apart', 897),
#  ('emotions', 894),
#  ('lovely', 894),
#  ('begin', 894),
#  ('doctor', 891),
#  ('party', 891),
#  ('italian', 891),
#  ('la', 888),
#  ('missed', 888),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 1684386),
#  ('.', 502614),
#  ('the', 490167),
#  ('a', 237963),
#  ('and', 223155),
#  ('of', 207027),
#  ('to', 206922),
#  ('br', 157911),
#  ('is', 150249),
#  ('it', 144981),
#  ('i', 140640),
#  ('in', 131259),
#  ('this', 122760),
#  ('that', 112845),
#  ('s', 94638),
#  ('was', 78873),
#  ('movie', 74895),
#  ('for', 65781),
#  ('but', 65343),
#  ('with', 62634),
#  ('as', 61875),
#  ('t', 61083),
#  ('film', 57654),
#  ('you', 52647),
#  ('on', 51576),
#  ('not', 49062),
#  ('have', 45432),
#  ('are', 43869),
#  ('be', 43623),
#  ('he', 41568),
#  ('one', 39402),
#  ('they', 39033),
#  ('at', 36837),
#  ('his', 36441),
#  ('all', 36108),
#  ('so', 34389),
#  ('like', 33714),
#  ('there', 32325),
#  ('just', 31857),
#  ('by', 31647),
#  ('or', 30816),
#  ('an', 30798),
#  ('who', 29907),
#  ('from', 29193),
#  ('if', 28554),
#  ('about', 27183),
#  ('out', 26937),
#  ('what', 25266),
#  ('some', 24918),
#  ('no', 24429),
#  ('her', 23841),
#  ('even', 23061),
#  ('can', 22959),
#  ('has', 22812),
#  ('good', 22269),
#  ('bad', 22203),
#  ('would', 21108),
#  ('up', 20910),
#  ('only', 20343),
#  ('more', 20190),
#  ('when', 20178),
#  ('she', 19332),
#  ('really', 18786),
#  ('time', 18627),
#  ('had', 18426),
#  ('my', 18045),
#  ('were', 18003),
#  ('which', 17340),
#  ('very', 17292),
#  ('me', 16818),
#  ('see', 16356),
#  ('don', 16008),
#  ('we', 15984),
#  ('their', 15834),
#  ('do', 15708),
#  ('story', 15624),
#  ('than', 15549),
#  ('been', 15300),
#  ('much', 15234),
#  ('get', 15111),
#  ('because', 14898),
#  ('people', 14418),
#  ('then', 14283),
#  ('make', 14166),
#  ('how', 14064),
#  ('could', 14058),
#  ('any', 13974),
#  ('into', 13701),
#  ('made', 13623),
#  ('first', 12918),
#  ('other', 12915),
#  ('well', 12762),
#  ('too', 12522),
#  ('them', 12495),
#  ('plot', 12462),
#  ('movies', 12240),
#  ('acting', 12168),
#  ('will', 11979),
#  ('way', 11967),
#  ('most', 11757),
#  ('him', 11574),
#  ('after', 11514),
#  ('its', 10965),
#  ('think', 10929),
#  ('also', 10824),
#  ('characters', 10800),
#  ('off', 10701),
#  ('watch', 10650),
#  ('character', 10518),
#  ('did', 10518),
#  ('why', 10389),
#  ('being', 10179),
#  ('better', 10074),
#  ('know', 10002),
#  ('over', 9948),
#  ('seen', 9795),
#  ('ever', 9789),
#  ('never', 9777),
#  ('your', 9699),
#  ('where', 9657),
#  ('two', 9519),
#  ('little', 9288),
#  ('films', 9231),
#  ('here', 9081),
#  ('m', 9000),
#  ('nothing', 8970),
#  ('say', 8946),
#  ('end', 8862),
#  ('something', 8826),
#  ('should', 8760),
#  ('many', 8727),
#  ('does', 8613),
#  ('thing', 8598),
#  ('show', 8586),
#  ('ve', 8487),
#  ('scene', 8448),
#  ('scenes', 8355),
#  ('these', 8172),
#  ('go', 8151),
#  ('didn', 7938),
#  ('great', 7920),
#  ('watching', 7920),
#  ('re', 7860),
#  ('doesn', 7803),
#  ('through', 7680),
#  ('such', 7632),
#  ('man', 7548),
#  ('worst', 7440),
#  ('actually', 7347),
#  ('actors', 7311),
#  ('life', 7287),
#  ('back', 7272),
#  ('while', 7254),
#  ('director', 7215),
#  ('funny', 7008),
#  ('going', 6957),
#  ('still', 6849),
#  ('another', 6762),
#  ('look', 6741),
#  ('now', 6711),
#  ('old', 6645),
#  ('those', 6636),
#  ('real', 6510),
#  ('few', 6474),
#  ('love', 6456),
#  ('horror', 6450),
#  ('before', 6441),
#  ('want', 6423),
#  ('minutes', 6378),
#  ('pretty', 6345),
#  ('best', 6282),
#  ('though', 6273),
#  ('same', 6243),
#  ('script', 6222),
#  ('work', 6081),
#  ('every', 6075),
#  ('seems', 6069),
#  ('least', 6033),
#  ('enough', 5991),
#  ('down', 5964),
#  ('original', 5949),
#  ('guy', 5892),
#  ('got', 5856),
#  ('around', 5829),
#  ('part', 5826),
#  ('lot', 5676),
#  ('anything', 5622),
#  ('find', 5580),
#  ('new', 5562),
#  ('again', 5547),
#  ('isn', 5547),
#  ('point', 5535),
#  ('things', 5517),
#  ('fact', 5517),
#  ('give', 5469),
#  ('makes', 5442),
#  ('take', 5400),
#  ('thought', 5394),
#  ('d', 5310),
#  ('whole', 5304),
#  ('long', 5283),
#  ('years', 5277),
#  ('however', 5220),
#  ('gets', 5142),
#  ('making', 5085),
#  ('cast', 5082),
#  ('big', 4986),
#  ('might', 4974),
#  ('interesting', 4944),
#  ('money', 4914),
#  ('us', 4884),
#  ('right', 4875),
#  ('far', 4857),
#  ('quite', 4788),
#  ('without', 4785),
#  ('come', 4785),
#  ('almost', 4722),
#  ('ll', 4701),
#  ('action', 4698),
#  ('awful', 4671),
#  ('kind', 4617),
#  ('reason', 4602),
#  ('am', 4590),
#  ('looks', 4584),
#  ('must', 4566),
#  ('done', 4530),
#  ('comedy', 4512),
#  ('someone', 4470),
#  ('trying', 4458),
#  ('wasn', 4452),
#  ('poor', 4443),
#  ('boring', 4434),
#  ('instead', 4434),
#  ('saw', 4425),
#  ('away', 4407),
#  ('girl', 4389),
#  ('probably', 4332),
#  ('believe', 4302),
#  ('sure', 4299),
#  ('looking', 4290),
#  ('stupid', 4284),
#  ('anyone', 4254),
#  ('times', 4218),
#  ('maybe', 4212),
#  ('world', 4212),
#  ('rather', 4182),
#  ('terrible', 4173),
#  ('may', 4170),
#  ('last', 4170),
#  ('since', 4164),
#  ('let', 4155),
#  ('tv', 4146),
#  ('hard', 4122),
#  ('between', 4122),
#  ('waste', 4074),
#  ('woman', 4068),
#  ('feel', 4062),
#  ('effects', 4044),
#  ('half', 4023),
#  ('own', 3999),
#  ('young', 3951),
#  ('music', 3948),
#  ('idea', 3936),
#  ('sense', 3918),
#  ('bit', 3894),
#  ('having', 3840),
#  ('book', 3834),
#  ('found', 3801),
#  ('put', 3789),
#  ('series', 3789),
#  ('goes', 3768),
#  ('worse', 3747),
#  ('said', 3690),
#  ('comes', 3672),
#  ('role', 3666),
#  ('main', 3660),
#  ('else', 3597),
#  ('everything', 3591),
#  ('yet', 3588),
#  ('low', 3567),
#  ('screen', 3564),
#  ('supposed', 3558),
#  ('actor', 3555),
#  ('either', 3549),
#  ('budget', 3537),
#  ('ending', 3537),
#  ('audience', 3534),
#  ('set', 3531),
#  ('family', 3510),
#  ('left', 3507),
#  ('completely', 3504),
#  ('both', 3474),
#  ('wrong', 3465),
#  ('always', 3453),
#  ('course', 3444),
#  ('place', 3444),
#  ('seem', 3441),
#  ('watched', 3426),
#  ('day', 3396),
#  ('simply', 3390),
#  ('shot', 3378),
#  ('mean', 3351),
#  ('special', 3306),
#  ('dead', 3303),
#  ('three', 3282),
#  ('house', 3255),
#  ('oh', 3252),
#  ('night', 3249),
#  ('read', 3246),
#  ('less', 3201),
#  ('high', 3198),
#  ('year', 3192),
#  ('camera', 3183),
#  ('worth', 3171),
#  ('our', 3168),
#  ('try', 3153),
#  ('horrible', 3138),
#  ('sex', 3138),
#  ('video', 3129),
#  ('black', 3117),
#  ('although', 3108),
#  ('couldn', 3108),
#  ('once', 3099),
#  ('rest', 3066),
#  ('dvd', 3063),
#  ('line', 3054),
#  ('played', 3051),
#  ('fun', 3021),
#  ('during', 3018),
#  ('production', 3009),
#  ('everyone', 3006),
#  ('play', 2979),
#  ('mind', 2970),
#  ('version', 2967),
#  ('kids', 2967),
#  ('seeing', 2964),
#  ('american', 2940),
#  ('given', 2934),
#  ('used', 2907),
#  ('performance', 2904),
#  ('especially', 2889),
#  ('together', 2889),
#  ('tell', 2877),
#  ('women', 2874),
#  ('start', 2868),
#  ('need', 2865),
#  ('second', 2859),
#  ('takes', 2850),
#  ('each', 2850),
#  ('wife', 2832),
#  ('dialogue', 2826),
#  ('use', 2820),
#  ('problem', 2814),
#  ('star', 2802),
#  ('unfortunately', 2793),
#  ('himself', 2787),
#  ('doing', 2778),
#  ('death', 2766),
#  ('name', 2763),
#  ('lines', 2757),
#  ('killer', 2742),
#  ('getting', 2739),
#  ('help', 2715),
#  ('couple', 2706),
#  ('fan', 2706),
#  ('head', 2694),
#  ('crap', 2685),
#  ('guess', 2664),
#  ('piece', 2652),
#  ('nice', 2640),
#  ('different', 2634),
#  ('school', 2628),
#  ('later', 2625),
#  ('entire', 2607),
#  ('shows', 2580),
#  ('next', 2574),
#  ('john', 2574),
#  ('short', 2571),
#  ('seemed', 2571),
#  ('hollywood', 2550),
#  ('home', 2544),
#  ('true', 2538),
#  ('person', 2538),
#  ('absolutely', 2526),
#  ('sort', 2520),
#  ('care', 2517),
#  ('understand', 2508),
#  ('plays', 2505),
#  ('felt', 2502),
#  ('written', 2487),
#  ('title', 2484),
#  ('men', 2466),
#  ('until', 2463),
#  ('flick', 2448),
#  ('decent', 2445),
#  ('face', 2442),
#  ('friends', 2430),
#  ('stars', 2421),
#  ('job', 2421),
#  ('case', 2421),
#  ('itself', 2412),
#  ('yes', 2403),
#  ('perhaps', 2400),
#  ('went', 2391),
#  ('wanted', 2391),
#  ('called', 2388),
#  ('annoying', 2385),
#  ('ridiculous', 2370),
#  ('tries', 2370),
#  ('laugh', 2364),
#  ('evil', 2361),
#  ('along', 2358),
#  ('top', 2355),
#  ('hour', 2352),
#  ('full', 2349),
#  ('came', 2340),
#  ('writing', 2340),
#  ('keep', 2310),
#  ('totally', 2301),
#  ('playing', 2298),
#  ('god', 2295),
#  ('won', 2292),
#  ('guys', 2289),
#  ('already', 2286),
#  ('gore', 2271),
#  ('direction', 2244),
#  ('save', 2238),
#  ('lost', 2235),
#  ('example', 2232),
#  ('sound', 2226),
#  ('war', 2223),
#  ('attempt', 2205),
#  ('car', 2199),
#  ('except', 2199),
#  ('moments', 2196),
#  ('blood', 2196),
#  ('obviously', 2190),
#  ('act', 2187),
#  ('remember', 2184),
#  ('kill', 2181),
#  ('truly', 2178),
#  ('white', 2178),
#  ('father', 2178),
#  ('b', 2175),
#  ('thinking', 2160),
#  ('ok', 2148),
#  ('finally', 2148),
#  ('turn', 2133),
#  ('quality', 2103),
#  ('lack', 2094),
#  ('style', 2082),
#  ('wouldn', 2079),
#  ('cheap', 2073),
#  ('none', 2070),
#  ('kid', 2058),
#  ('please', 2058),
#  ('boy', 2055),
#  ('seriously', 2052),
#  ('lead', 2040),
#  ('dull', 2031),
#  ('children', 2028),
#  ('starts', 2025),
#  ('stuff', 2019),
#  ('hope', 2016),
#  ('looked', 2010),
#  ('recommend', 2007),
#  ('under', 2004),
#  ('run', 2001),
#  ('killed', 2001),
#  ('enjoy', 1998),
#  ('others', 1998),
#  ('etc', 1989),
#  ('myself', 1989),
#  ('beginning', 1986),
#  ('girls', 1986),
#  ('against', 1986),
#  ('obvious', 1980),
#  ('small', 1980),
#  ('hell', 1977),
#  ('slow', 1971),
#  ('hand', 1968),
#  ('wonder', 1956),
#  ('lame', 1956),
#  ('becomes', 1953),
#  ('picture', 1953),
#  ('based', 1950),
#  ('early', 1944),
#  ('behind', 1938),
#  ('poorly', 1932),
#  ('avoid', 1926),
#  ('apparently', 1920),
#  ('complete', 1920),
#  ('happens', 1917),
#  ('anyway', 1914),
#  ('classic', 1911),
#  ('several', 1908),
#  ('despite', 1905),
#  ('certainly', 1905),
#  ('episode', 1905),
#  ('often', 1893),
#  ('cut', 1890),
#  ('writer', 1890),
#  ('mother', 1884),
#  ('predictable', 1884),
#  ('gave', 1884),
#  ('become', 1881),
#  ('close', 1875),
#  ('fans', 1872),
#  ('saying', 1863),
#  ('scary', 1857),
#  ('stop', 1854),
#  ('live', 1854),
#  ('wants', 1851),
#  ('self', 1845),
#  ('mr', 1836),
#  ('jokes', 1833),
#  ('friend', 1833),
#  ('cannot', 1830),
#  ('overall', 1827),
#  ('cinema', 1812),
#  ('child', 1809),
#  ('silly', 1803),
#  ('beautiful', 1788),
#  ('human', 1785),
#  ('expect', 1782),
#  ('liked', 1779),
#  ('happened', 1776),
#  ('bunch', 1770),
#  ('entertaining', 1770),
#  ('actress', 1764),
#  ('final', 1764),
#  ('says', 1752),
#  ('performances', 1752),
#  ('turns', 1731),
#  ('humor', 1731),
#  ('themselves', 1728),
#  ('eyes', 1728),
#  ('hours', 1722),
#  ('happen', 1719),
#  ('basically', 1716),
#  ('days', 1716),
#  ('running', 1713),
#  ('involved', 1707),
#  ('disappointed', 1707),
#  ('call', 1707),
#  ('directed', 1704),
#  ('group', 1704),
#  ('fight', 1701),
#  ('daughter', 1698),
#  ('talking', 1698),
#  ('body', 1698),
#  ('badly', 1695),
#  ('sorry', 1695),
#  ('throughout', 1689),
#  ('viewer', 1689),
#  ('yourself', 1686),
#  ('extremely', 1686),
#  ('interest', 1683),
#  ('heard', 1683),
#  ('violence', 1683),
#  ('shots', 1677),
#  ('side', 1671),
#  ('word', 1668),
#  ('art', 1665),
#  ('possible', 1662),
#  ('dark', 1653),
#  ('game', 1653),
#  ('hero', 1650),
#  ('alone', 1647),
#  ('son', 1641),
#  ('type', 1641),
#  ('leave', 1641),
#  ('gives', 1638),
#  ('parts', 1638),
#  ('single', 1638),
#  ('started', 1635),
#  ('female', 1629),
#  ('rating', 1623),
#  ('mess', 1623),
#  ('voice', 1623),
#  ('aren', 1620),
#  ('town', 1620),
#  ('drama', 1614),
#  ('definitely', 1611),
#  ('unless', 1608),
#  ('review', 1602),
#  ('effort', 1599),
#  ('weak', 1599),
#  ('able', 1599),
#  ('took', 1593),
#  ('non', 1590),
#  ('five', 1590),
#  ('matter', 1587),
#  ('usually', 1587),
#  ('michael', 1584),
#  ('feeling', 1578),
#  ('huge', 1569),
#  ('sequel', 1566),
#  ('soon', 1563),
#  ('exactly', 1560),
#  ('past', 1557),
#  ('turned', 1554),
#  ('police', 1554),
#  ('tried', 1545),
#  ('middle', 1539),
#  ('talent', 1539),
#  ('genre', 1536),
#  ('zombie', 1530),
#  ('ends', 1527),
#  ('history', 1527),
#  ('straight', 1509),
#  ('opening', 1503),
#  ('serious', 1503),
#  ('coming', 1503),
#  ('moment', 1500),
#  ('lives', 1497),
#  ('sad', 1497),
#  ('dialog', 1494),
#  ('particularly', 1494),
#  ('editing', 1479),
#  ('clearly', 1476),
#  ('beyond', 1473),
#  ('earth', 1473),
#  ('taken', 1470),
#  ('cool', 1470),
#  ('level', 1467),
#  ('dumb', 1467),
#  ('okay', 1464),
#  ('major', 1461),
#  ('fast', 1455),
#  ('premise', 1455),
#  ('joke', 1452),
#  ('stories', 1452),
#  ('wasted', 1449),
#  ('minute', 1449),
#  ('across', 1446),
#  ('mostly', 1446),
#  ('rent', 1446),
#  ('late', 1443),
#  ('falls', 1443),
#  ('fails', 1443),
#  ('mention', 1434),
#  ('theater', 1425),
#  ('stay', 1416),
#  ('sometimes', 1416),
#  ('hit', 1404),
#  ('talk', 1401),
#  ('fine', 1401),
#  ('die', 1398),
#  ('storyline', 1395),
#  ('pointless', 1395),
#  ('taking', 1392),
#  ('order', 1386),
#  ('brother', 1383),
#  ('whatever', 1380),
#  ('told', 1380),
#  ('wish', 1374),
#  ('room', 1368),
#  ('career', 1365),
#  ('appears', 1365),
#  ('write', 1365),
#  ('known', 1362),
#  ('husband', 1362),
#  ('living', 1353),
#  ('sit', 1350),
#  ('ten', 1350),
#  ('words', 1347),
#  ('monster', 1344),
#  ('chance', 1344),
#  ('hate', 1332),
#  ('novel', 1332),
#  ('add', 1329),
#  ('english', 1329),
#  ('somehow', 1323),
#  ('strange', 1320),
#  ('imdb', 1314),
#  ('actual', 1314),
#  ('total', 1311),
#  ('material', 1311),
#  ('killing', 1311),
#  ('ones', 1311),
#  ('knew', 1308),
#  ('king', 1302),
#  ('number', 1302),
#  ('using', 1299),
#  ('lee', 1293),
#  ('power', 1293),
#  ('shown', 1293),
#  ('works', 1293),
#  ('giving', 1293),
#  ('points', 1290),
#  ('possibly', 1290),
#  ('kept', 1290),
#  ('four', 1287),
#  ('local', 1281),
#  ('usual', 1278),
#  ('including', 1275),
#  ('problems', 1272),
#  ('ago', 1272),
#  ('opinion', 1272),
#  ('nudity', 1269),
#  ('age', 1266),
#  ('due', 1263),
#  ('roles', 1260),
#  ('writers', 1257),
#  ('decided', 1257),
#  ('near', 1254),
#  ('flat', 1254),
#  ('easily', 1254),
#  ('murder', 1251),
#  ('experience', 1251),
#  ('reviews', 1248),
#  ('imagine', 1245),
#  ('feels', 1239),
#  ('plain', 1233),
#  ('somewhat', 1233),
#  ('class', 1230),
#  ('score', 1230),
#  ('song', 1227),
#  ('bring', 1227),
#  ('whether', 1227),
#  ('otherwise', 1224),
#  ('whose', 1224),
#  ('average', 1224),
#  ('pathetic', 1221),
#  ('nearly', 1221),
#  ('knows', 1221),
#  ('zombies', 1221),
#  ('cinematography', 1218),
#  ('cheesy', 1218),
#  ('upon', 1218),
#  ('city', 1215),
#  ('space', 1215),
#  ('credits', 1212),
#  ('james', 1209),
#  ('lots', 1209),
#  ('change', 1209),
#  ('entertainment', 1206),
#  ('nor', 1206),
#  ('wait', 1203),
#  ('released', 1200),
#  ('needs', 1197),
#  ('shame', 1194),
#  ('attention', 1188),
#  ('comments', 1182),
#  ('bored', 1179),
#  ('free', 1179),
#  ('lady', 1179),
#  ('expected', 1176),
#  ('needed', 1176),
#  ('clear', 1176),
#  ('view', 1173),
#  ('development', 1170),
#  ('check', 1170),
#  ('doubt', 1170),
#  ('figure', 1167),
#  ('mystery', 1167),
#  ('excellent', 1164),
#  ('garbage', 1164),
#  ('sequence', 1158),
#  ('television', 1158),
#  ('o', 1155),
#  ('sets', 1155),
#  ('laughable', 1152),
#  ('potential', 1152),
#  ('robert', 1146),
#  ('light', 1146),
#  ('country', 1146),
#  ('documentary', 1146),
#  ('reality', 1146),
#  ('general', 1143),
#  ('ask', 1143),
#  ('comic', 1140),
#  ('fall', 1140),
#  ('begin', 1140),
#  ('footage', 1137),
#  ('stand', 1137),
#  ('forced', 1137),
#  ('trash', 1137),
#  ('remake', 1137),
#  ('thriller', 1134),
#  ('songs', 1134),
#  ('gay', 1131),
#  ('within', 1131),
#  ('hardly', 1128),
#  ('above', 1125),
#  ('gone', 1125),
#  ('george', 1122),
#  ('means', 1119),
#  ('sounds', 1119),
#  ('directing', 1116),
#  ('move', 1116),
#  ('david', 1116),
#  ('buy', 1116),
#  ('rock', 1113),
#  ('forward', 1113),
#  ('important', 1113),
#  ('hot', 1110),
#  ('haven', 1110),
#  ('filmed', 1110),
#  ('british', 1110),
#  ('heart', 1107),
#  ('reading', 1107),
#  ('fake', 1107),
#  ('incredibly', 1104),
#  ('weird', 1104),
#  ('hear', 1104),
#  ('enjoyed', 1101),
#  ('hilarious', 1101),
#  ('cop', 1101),
#  ('musical', 1101),
#  ('message', 1098),
#  ('happy', 1098),
#  ('pay', 1098),
#  ('laughs', 1095),
#  ('box', 1095),
#  ('suspense', 1089),
#  ('sadly', 1089),
#  ('eye', 1086),
#  ('third', 1083),
#  ('similar', 1083),
#  ('named', 1083),
#  ('modern', 1080),
#  ('failed', 1077),
#  ('events', 1077),
#  ('forget', 1074),
#  ('question', 1074),
#  ('male', 1071),
#  ('finds', 1071),
#  ('perfect', 1068),
#  ('spent', 1065),
#  ('sister', 1065),
#  ('feature', 1062),
#  ('result', 1062),
#  ('comment', 1059),
#  ('girlfriend', 1059),
#  ('sexual', 1056),
#  ('attempts', 1053),
#  ('neither', 1053),
#  ('richard', 1053),
#  ('screenplay', 1050),
#  ('elements', 1050),
#  ('spoilers', 1047),
#  ('brain', 1044),
#  ('filmmakers', 1044),
#  ('showing', 1044),
#  ('miss', 1041),
#  ('dr', 1041),
#  ('christmas', 1041),
#  ('cover', 1035),
#  ('red', 1032),
#  ('sequences', 1032),
#  ('typical', 1029),
#  ('excuse', 1029),
#  ('crazy', 1026),
#  ('ideas', 1026),
#  ('baby', 1026),
#  ('loved', 1023),
#  ('meant', 1023),
#  ('worked', 1020),
#  ('fire', 1020),
#  ('unbelievable', 1017),
#  ('follow', 1017),
#  ('theme', 1011),
#  ('barely', 1008),
#  ('producers', 1008),
#  ('twist', 1008),
#  ('plus', 1008),
#  ('appear', 1008),
#  ('directors', 1005),
#  ('team', 1005),
#  ('viewers', 999),
#  ('leads', 996),
#  ('tom', 996),
#  ('slasher', 996),
#  ('wrote', 993),
#  ('villain', 993),
#  ('gun', 993),
#  ('working', 993),
#  ('island', 990),
#  ('strong', 990),
#  ('open', 990),
#  ('realize', 990),
#  ('positive', 987),
#  ('disappointing', 987),
#  ('yeah', 987),
#  ('quickly', 987),
#  ('weren', 984),
#  ('release', 984),
#  ('simple', 984),
#  ('honestly', 984),
#  ('eventually', 981),
#  ('period', 981),
#  ('tells', 981),
#  ('kills', 981),
#  ('doctor', 981),
#  ('nowhere', 978),
#  ('list', 978),
#  ('acted', 978),
#  ('herself', 978),
#  ('dog', 978),
#  ('walk', 975),
#  ('air', 972),
#  ('apart', 972),
#  ('makers', 969),
#  ('subject', 969),
#  ('learn', 966),
#  ('fi', 966),
#  ('sci', 957),
#  ('bother', 957),
#  ('admit', 957),
#  ('jack', 954),
#  ('disappointment', 954),
#  ('hands', 954),
#  ('note', 954),
#  ('certain', 951),
#  ('e', 951),
#  ('value', 951),
#  ('casting', 951),
#  ('grade', 948),
#  ('peter', 948),
#  ('suddenly', 945),
#  ('missing', 945),
#  ('form', 939),
#  ('stick', 939),
#  ('previous', 939),
#  ('break', 939),
#  ('soundtrack', 936),
#  ('surprised', 933),
#  ('front', 933),
#  ('expecting', 933),
#  ('parents', 930),
#  ('surprise', 930),
#  ('relationship', 930),
#  ('shoot', 927),
#  ('today', 927),
#  ('painful', 924),
#  ('ways', 924),
#  ('leaves', 924),
#  ('ended', 924),
#  ('creepy', 924),
#  ('concept', 924),
#  ('somewhere', 924),
#  ('vampire', 924),
#  ('spend', 921),
#  ('th', 921),
#  ('future', 918),
#  ('difficult', 918),
#  ('effect', 918),
#  ('fighting', 918),
#  ('street', 918),
#  ('c', 915),
#  ('america', 915),
#  ('accent', 912),
#  ('truth', 906),
#  ('project', 906),
#  ('joe', 903),
#  ('f', 903),
#  ('deal', 903),
#  ('indeed', 903),
#  ('biggest', 900),
#  ('rate', 900),
#  ('paul', 897),
#  ('japanese', 897),
#  ('utterly', 894),
#  ('begins', 894),
#  ('redeeming', 894),
#  ('college', 894),
#  ('york', 891),
#  ('fairly', 891),
#  ('disney', 891),
#  ('crew', 888),
#  ('create', 888),
#  ('cartoon', 888),
#  ('revenge', 888),
#  ('co', 885),
#  ('outside', 885),
#  ('computer', 885),
#  ('interested', 885),
#  ('stage', 885),
#  ('considering', 882),
#  ('speak', 882),
#  ('among', 882),
#  ('towards', 879),
#  ('channel', 879),
#  ('sick', 879),
#  ('talented', 876),
#  ('cause', 876),
#  ('particular', 876),
#  ('van', 876),
#  ('hair', 876),
#  ('bottom', 873),
#  ('reasons', 873),
#  ('mediocre', 870),
#  ('cat', 870),
#  ('telling', 870),
#  ('supporting', 867),
#  ('store', 867),
#  ('hoping', 864),
#  ('waiting', 864),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
for string, num in total_counts.most_common():
    #       Consider words to be "common" if they've been used at least 100 times
    if num >= 100:
        pos_neg_ratios[string] = positive_counts[string] / (negative_counts[string] + 1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0608036428326615
# Pos-to-neg ratio for 'amazing' = 4.033036848792884
# Pos-to-neg ratio for 'terrible' = 0.17752755150934355

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
for s, n in pos_neg_ratios.most_common():
    pos_neg_ratios[s] = np.log(n)

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902677448642055
# Pos-to-neg ratio for 'amazing' = 1.3945196526689512
# Pos-to-neg ratio for 'terrible' = -1.7286294623410592

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.7899601708972535),
#  ('paulie', 4.4830025520138834),
#  ('felix', 3.2958368660043291),
#  ('polanski', 2.9411440832695881),
#  ('matthau', 2.8836827697453682),
#  ('victoria', 2.7264839027910481),
#  ('mildred', 2.6897010624340134),
#  ('gandhi', 2.6159349121944042),
#  ('flawless', 2.5199979695992702),
#  ('superbly', 2.3171838924151982),
#  ('perfection', 2.2049466234301298),
#  ('astaire', 2.1888563276657029),
#  ('voight', 2.082814226158475),
#  ('captures', 2.0656482195475001),
#  ('wonderfully', 2.0395956331326364),
#  ('powell', 2.0043209112117277),
#  ('brosnan', 1.9973587108913553),
#  ('lily', 1.9603821816638478),
#  ('bakshi', 1.9429904389519785),
#  ('lincoln', 1.9308722716907727),
#  ('lemmon', 1.8912890645750882),
#  ('refreshing', 1.8792788472446116),
#  ('breathtaking', 1.87752629098548),
#  ('bourne', 1.8738244222823592),
#  ('flynn', 1.8319255109533896),
#  ('delightful', 1.8175119653304697),
#  ('homer', 1.8147489874527538),
#  ('andrews', 1.8072636557640203),
#  ('soccer', 1.8033202916291311),
#  ('lumet', 1.791759469228055),
#  ('beautifully', 1.7731666361514391),
#  ('elvira', 1.7691169924782952),
#  ('gripping', 1.7459499331967607),
#  ('underrated', 1.7384781026151184),
#  ('superb', 1.7156449752072436),
#  ('sadness', 1.7012454616872232),
#  ('delight', 1.6985019757414723),
#  ('welles', 1.6845139388744574),
#  ('timeless', 1.6631420914059614),
#  ('macy', 1.6611392868109909),
#  ('sinatra', 1.6558038329920262),
#  ('hartley', 1.6494432470477995),
#  ('touching', 1.6466515087745348),
#  ('unforgettable', 1.6459075922154918),
#  ('favorites', 1.6376087894007967),
#  ('extraordinary', 1.6326947745983675),
#  ('sullivan', 1.6304913216319328),
#  ('stewart', 1.6205824769871655),
#  ('brilliantly', 1.611049516328442),
#  ('palma', 1.5910887737659039),
#  ('friendship', 1.5814640603916943),
#  ('ritter', 1.5686159179138452),
#  ('wonderful', 1.5668681749696849),
#  ('magnificent', 1.5612358106162227),
#  ('jackie', 1.5603171150991502),
#  ('finest', 1.5599578551707307),
#  ('tremendous', 1.5478800194346669),
#  ('freedom', 1.5243826629370196),
#  ('pleasantly', 1.5188924825614147),
#  ('mann', 1.5188924825614147),
#  ('sidney', 1.5143338969434632),
#  ('terrific', 1.5111445639993666),
#  ('fantastic', 1.5094516899420509),
#  ('nancy', 1.5040773967762742),
#  ('noir', 1.50262073227981),
#  ('outstanding', 1.4997010221764751),
#  ('marie', 1.4968571488027869),
#  ('marvelous', 1.4964727973910548),
#  ('ruth', 1.4890395194117334),
#  ('excellent', 1.4664691168591149),
#  ('stanwyck', 1.4629501053524112),
#  ('widmark', 1.4575573811413813),
#  ('splendid', 1.455287232606842),
#  ('tender', 1.4448885253859434),
#  ('exceptional', 1.4434527749598391),
#  ('chan', 1.4399154525589883),
#  ('gentle', 1.4372144515471477),
#  ('poignant', 1.4240346891027378),
#  ('captivating', 1.4144652380865868),
#  ('fisher', 1.4122698475231514),
#  ('davies', 1.4122698475231514),
#  ('chilling', 1.4060969884160703),
#  ('gem', 1.402517196626778),
#  ('amazing', 1.3945196526689512),
#  ('darker', 1.3934118288887545),
#  ('april', 1.3821875791672373),
#  ('blake', 1.37125648375535),
#  ('overlooked', 1.3541372494853594),
#  ('kelly', 1.3536931997444925),
#  ('ralph', 1.3499267169490159),
#  ('cole', 1.3362839405452291),
#  ('bette', 1.3360856655371443),
#  ('hoffman', 1.3318739701479041),
#  ('shines', 1.3260021308637706),
#  ('winters', 1.3127602770737414),
#  ('notch', 1.3106710075578265),
#  ('powerful', 1.3049914138340664),
#  ('vivid', 1.3044643428722584),
#  ('pitt', 1.3022112439093492),
#  ('giallo', 1.3004784415350346),
#  ('remarkable', 1.2983689072841658),
#  ('psychiatrist', 1.2935126276689244),
#  ('portrait', 1.2915159547926012),
#  ('gritty', 1.2913778046231477),
#  ('innocence', 1.2892326482767593),
#  ('garbo', 1.2883688239495823),
#  ('ensemble', 1.286075244962483),
#  ('holly', 1.2809338454620642),
#  ('panic', 1.2787384548986287),
#  ('burns', 1.2766875545806133),
#  ('philip', 1.2714551015075206),
#  ('barbara', 1.2704625455947689),
#  ('carol', 1.2698840092754793),
#  ('stunning', 1.26967669093743),
#  ('favorite', 1.2693586852184033),
#  ('rural', 1.2625001437732262),
#  ('appreciated', 1.2615157596049626),
#  ('brooklyn', 1.2568362938830038),
#  ('builds', 1.2565153181139184),
#  ('favourite', 1.2501621867953105),
#  ('perfect', 1.2486116401364886),
#  ('unfolds', 1.2445662012911896),
#  ('journey', 1.2435194096118067),
#  ('von', 1.2411753533229801),
#  ('bond', 1.2408393882601862),
#  ('brilliant', 1.2312184691988761),
#  ('recommended', 1.2223654913109969),
#  ('daniel', 1.2143482407027684),
#  ('crafted', 1.2134925646665318),
#  ('troubled', 1.2119409739751128),
#  ('consequences', 1.2098379237783341),
#  ('prince', 1.2034919194885851),
#  ('perfectly', 1.2017077976950838),
#  ('alexander', 1.1992558144477972),
#  ('boxing', 1.195986452693286),
#  ('haunting', 1.1939224684724346),
#  ('solo', 1.1939224684724346),
#  ('cinderella', 1.1922478937021024),
#  ('curtis', 1.1847899849091621),
#  ('emotions', 1.1825776687854439),
#  ('subtle', 1.1799070310613564),
#  ('daughters', 1.1686798512848267),
#  ('rare', 1.1629530054335593),
#  ('courage', 1.1625610132683832),
#  ('dentist', 1.1608545975453306),
#  ('loved', 1.1583173701898661),
#  ('draws', 1.1557707025080584),
#  ('nominated', 1.1533371883573562),
#  ('everyday', 1.1470088295299599),
#  ('tony', 1.1450123642728738),
#  ('cried', 1.144597401909933),
#  ('highly', 1.1444218246994038),
#  ('fay', 1.1430640512389434),
#  ('contrast', 1.1406605249116091),
#  ('corruption', 1.1388861878060497),
#  ('fabulous', 1.1363526166509568),
#  ('ned', 1.1355168456035607),
#  ('emma', 1.1318379362964301),
#  ('smooth', 1.1300284849014886),
#  ('sensitive', 1.1282440862744809),
#  ('dramas', 1.1273223945505411),
#  ('inspiring', 1.1184149159642893),
#  ('stellar', 1.1116843702354624),
#  ('helps', 1.1097441290369539),
#  ('today', 1.1071960323595011),
#  ('jimmy', 1.1034784783192826),
#  ('awesome', 1.0986122886681098),
#  ('rival', 1.0986122886681098),
#  ('depression', 1.0986122886681098),
#  ('shy', 1.0986122886681098),
#  ('carrie', 1.0986122886681098),
#  ('blend', 1.0986122886681098),
#  ('hank', 1.0986122886681098),
#  ('diana', 1.0986122886681098),
#  ('adorable', 1.0986122886681098),
#  ('tragic', 1.0947881922297062),
#  ('intense', 1.0947438118901893),
#  ('unique', 1.0923163602112951),
#  ('achievement', 1.0879169995513618),
#  ('provides', 1.0872269664429843),
#  ('glorious', 1.0858732628906798),
#  ('unexpected', 1.0826968333622102),
#  ('bettie', 1.0823517677963295),
#  ('happiness', 1.0772591641975406),
#  ('ideal', 1.072969858054772),
#  ('terrifying', 1.070703500551033),
#  ('fears', 1.0671960924347308),
#  ('davis', 1.0614332854263557),
#  ('hong', 1.0572270725052555),
#  ('beauty', 1.0543394649901214),
#  ('seasons', 1.0541605260972757),
#  ('definite', 1.0536609008058433),
#  ('carries', 1.0502157478062595),
#  ('fascinating', 1.04801127537432),
#  ('touched', 1.0445450673978338),
#  ('satisfying', 1.0438873889788631),
#  ('aunt', 1.037987666851675),
#  ('enterprise', 1.0356984632575403),
#  ('creates', 1.0344191310290498),
#  ('walter', 1.0336927425687941),
#  ('spectacular', 1.0299837822790134),
#  ('greatest', 1.0282845465260535),
#  ('musicals', 1.02395075989909),
#  ('portrayal', 1.0239315241359586),
#  ('ann', 1.0214765597858824),
#  ('mature', 1.0197183461984467),
#  ('triumph', 1.0185695809945732),
#  ('margaret', 1.0185695809945732),
#  ('deeply', 1.0172666492141573),
#  ('incredible', 1.0105925421264641),
#  ('navy', 1.0102013313240568),
#  ('lucas', 1.0076405104623831),
#  ('joey', 1.0071780827084778),
#  ('balance', 1.001762462678192),
#  ('widow', 0.99976645403147713),
#  ('carrey', 0.99952138602387874),
#  ('guilt', 0.9980710594462322),
#  ('glover', 0.9980710594462322),
#  ('brazil', 0.99796876288842229),
#  ('harry', 0.99711679937665576),
#  ('awe', 0.9959581346080264),
#  ('warm', 0.99566431941566724),
#  ('essence', 0.99523393421427453),
#  ('ages', 0.9943512783437003),
#  ('sons', 0.99416962530051234),
#  ('sweet', 0.99397145638067697),
#  ('sport', 0.99072332665692475),
#  ('oscar', 0.99007212009290368),
#  ('learns', 0.98962200495970465),
#  ('eerie', 0.98840914853449546),
#  ('holmes', 0.98738665355788524),
#  ('destiny', 0.98669437246412428),
#  ('unusual', 0.98575779921287532),
#  ('complex', 0.98333327864491671),
#  ('lonely', 0.98164061208260556),
#  ('grim', 0.98164061208260556),
#  ('solid', 0.98022227271994955),
#  ('vhs', 0.97975108579138082),
#  ('thrillers', 0.97881108885548895),
#  ('ginger', 0.97798430087949495),
#  ('debut', 0.97438328870590063),
#  ('beautiful', 0.97438033118040313),
#  ('cox', 0.97161259790680232),
#  ('comfortable', 0.96977941682514124),
#  ('hooked', 0.96880067714611906),
#  ('stanley', 0.96815940027067449),
#  ('tears', 0.96721082230141198),
#  ('rose', 0.96649432384073408),
#  ('winning', 0.96161468806710093),
#  ('feelings', 0.96159049110381856),
#  ('paris', 0.95870196733281521),
#  ('mgm', 0.95643779988756705),
#  ('heart', 0.95419149624431876),
#  ('perry', 0.95251967017061379),
#  ('mysteries', 0.95200881447623431),
#  ('hal', 0.95200881447623431),
#  ('lovable', 0.94721264221274126),
#  ('danny', 0.94686545615224593),
#  ('themes', 0.94680627580010557),
#  ('masterpiece', 0.94543389865979066),
#  ('anime', 0.94363618576468389),
#  ('joy', 0.94108208551619899),
#  ('louis', 0.93918455174000759),
#  ('lifestyle', 0.9387635877262136),
#  ('urban', 0.93609335917033476),
#  ('gradually', 0.93609335917033476),
#  ('italy', 0.93155820400494349),
#  ('kennedy', 0.93155820400494349),
#  ('allows', 0.9311333049120839),
#  ('charming', 0.9301936370431465),
#  ('subsequent', 0.92979141909305774),
#  ('impact', 0.92440816639412171),
#  ('spy', 0.9242589015233319),
#  ('winter', 0.9230475143370348),
#  ('treat', 0.91920618583427904),
#  ('highest', 0.91848612243759076),
#  ('secrets', 0.91835046483716565),
#  ('pleased', 0.91812391295581597),
#  ('norman', 0.91812391295581597),
#  ('raw', 0.91761435880466335),
#  ('reveals', 0.91756380652095326),
#  ('surprising', 0.91706263465273685),
#  ('loving', 0.91702846706069463),
#  ('quiet', 0.91465004241669523),
#  ('thief', 0.91334522164439824),
#  ('colorful', 0.91305971129270846),
#  ('danes', 0.91228271047661635),
#  ('funniest', 0.90721743566848023),
#  ('kudos', 0.90707407676923102),
#  ('bleak', 0.90653455692879026),
#  ('todd', 0.9059279448386085),
#  ('season', 0.90125285450961445),
#  ('compelling', 0.90059940207947953),
#  ('subtitles', 0.89927938604761848),
#  ('baseball', 0.89794159320595857),
#  ('castle', 0.89643386581894491),
#  ('winner', 0.89629006516748555),
#  ('fonda', 0.89334916263174846),
#  ('tragedy', 0.89194615997641746),
#  ('great', 0.88835717051560825),
#  ('eastwood', 0.88778922174194053),
#  ('essential', 0.88771735943009911),
#  ('nicely', 0.88685405957902519),
#  ('focuses', 0.8832508777959549),
#  ('intensity', 0.88263722683251256),
#  ('arthur', 0.88154778343028206),
#  ('worlds', 0.8793980154937896),
#  ('gorgeous', 0.87930751366106563),
#  ('health', 0.87753272157475148),
#  ('witty', 0.87650554408234016),
#  ('natural', 0.8748573035225613),
#  ('rob', 0.87322406750007597),
#  ('enjoyed', 0.87251519664042698),
#  ('magical', 0.87109873768278145),
#  ('deeper', 0.87068022062210282),
#  ('purple', 0.87060254770272694),
#  ('lucy', 0.87017304977918963),
#  ('sings', 0.86222351060387925),
#  ('craig', 0.86161170269247378),
#  ('modesty', 0.86161170269247378),
#  ('moving', 0.85828391259979897),
#  ('lovely', 0.85816957009108785),
#  ('tear', 0.85304170156645565),
#  ('relate', 0.85269962909262387),
#  ('memorable', 0.85135079238637523),
#  ('disagree', 0.84971624125148526),
#  ('hart', 0.84577694754649702),
#  ('episodes', 0.84459561250066584),
#  ('smith', 0.84408242353322926),
#  ('princess', 0.84408242353322926),
#  ('strong', 0.84368748748579392),
#  ('dave', 0.84189244182029577),
#  ('kung', 0.84078317936600999),
#  ('jake', 0.84037741754262996),
#  ('apartment', 0.83982468221604378),
#  ('forbidden', 0.83808120528227958),
#  ('columbo', 0.83731697138952366),
#  ('adventure', 0.83581596543390602),
#  ('realizes', 0.83458919053297564),
#  ('strength', 0.83310407371065087),
#  ('manager', 0.83140874755986938),
#  ('adds', 0.83135005522507155),
#  ('tight', 0.83081158677015776),
#  ('dancer', 0.83034830207343024),
#  ('surreal', 0.82832195892819782),
#  ('childhood', 0.82821585250335439),
#  ('explicit', 0.82610501423556382),
#  ('miike', 0.82461032012040891),
#  ('carl', 0.82417544296634937),
#  ('studios', 0.82290640726304443),
#  ('con', 0.82290640726304443),
#  ('kurt', 0.8206863911616934),
#  ('abc', 0.81958827895944342),
#  ('dances', 0.8179973834394213),
#  ('eyre', 0.81719982922992418),
#  ('touches', 0.81443284676753092),
#  ('traditional', 0.81372742083739003),
#  ('deals', 0.81372742083739003),
#  ('develops', 0.81343334643444731),
#  ('sides', 0.81322642847667892),
#  ('holds', 0.81213286218208913),
#  ('realistic', 0.81093021621632877),
#  ('gene', 0.81093021621632877),
#  ('albert', 0.81093021621632877),
#  ('oscars', 0.81093021621632877),
#  ('importance', 0.81093021621632877),
#  ('waters', 0.81093021621632877),
#  ('empire', 0.80802745655836727),
#  ('legendary', 0.80717786659777835),
#  ('cry', 0.80551014874698945),
#  ('styles', 0.80462104702306403),
#  ('daring', 0.80462104702306403),
#  ('hearted', 0.80449932588603823),
#  ('backgrounds', 0.80381274844746464),
#  ('matches', 0.80381274844746464),
#  ('portraying', 0.80299996054035117),
#  ('sentimental', 0.80107791977331722),
#  ('environment', 0.80065263345808846),
#  ('impressed', 0.79866012362451444),
#  ('gothic', 0.7977199844795223),
#  ('tense', 0.79674558122437233),
#  ('achieved', 0.79542602968036358),
#  ('edge', 0.79461664072480498),
#  ('jean', 0.79453640644065238),
#  ('captured', 0.79440091426511816),
#  ('sharp', 0.79174915736448481),
#  ('court', 0.79046438562403765),
#  ('forms', 0.78942401099536508),
#  ('steals', 0.78891408565195376),
#  ('rules', 0.78761913734788169),
#  ('colors', 0.78748459764164791),
#  ('frank', 0.78739971880613457),
#  ('reunion', 0.78717613020822175),
#  ('covers', 0.78702469536277442),
#  ('blob', 0.78449695914817319),
#  ('denzel', 0.78297413894973866),
#  ('conventional', 0.78137141397478438),
#  ('stays', 0.77943154915695767),
#  ('rain', 0.77884190166482825),
#  ('landscape', 0.7767122589059875),
#  ('maria', 0.77411624309361238),
#  ('tale', 0.77277845025195258),
#  ('midnight', 0.77273461847829272),
#  ('immensely', 0.77239655221408576),
#  ('spring', 0.77057892069276135),
#  ('cagney', 0.77057892069276135),
#  ('titanic', 0.76764970785786635),
#  ('sunday', 0.76764970785786635),
#  ('fresh', 0.76715538716262921),
#  ('sir', 0.76214005204689672),
#  ('animated', 0.76173429022351669),
#  ('nowadays', 0.75963692182877829),
#  ('nevertheless', 0.75948165438028681),
#  ('driven', 0.75864048592063238),
#  ('leslie', 0.75730912477723111),
#  ('enjoyable', 0.7549359468617538),
#  ('memories', 0.7546493803177392),
#  ('influenced', 0.75434274158686498),
#  ('florida', 0.75434274158686498),
#  ('packed', 0.75416128631509149),
#  ('golden', 0.75330110337969247),
#  ('strikes', 0.75286641526156761),
#  ('che', 0.75233605195027597),
#  ('lovers', 0.75208971619339537),
#  ('secretary', 0.75155794271635978),
#  ('provoking', 0.75082629214662333),
#  ('performances', 0.74997277613936308),
#  ('depiction', 0.74879843510932265),
#  ('simple', 0.74844260800282525),
#  ('trek', 0.74827925125466166),
#  ('elderly', 0.74812931497729829),
#  ('relationship', 0.74698824702629452),
#  ('supporting', 0.74587953117511652),
#  ('blues', 0.74340901534083359),
#  ('germany', 0.74193734472937733),
#  ('emotional', 0.7399169152621865),
#  ('bears', 0.73983429453259852),
#  ('lewis', 0.73873392501183954),
#  ('bugs', 0.73612900313363039),
#  ('china', 0.73570679497874125),
#  ('verhoeven', 0.73570679497874125),
#  ('owner', 0.73521839448063231),
#  ('anger', 0.73503812226910548),
#  ('portrays', 0.7348656341272376),
#  ('brings', 0.73468669900126871),
#  ('streets', 0.73427447198380813),
#  ('henry', 0.7314471056474906),
#  ('available', 0.72942058734678028),
#  ('endearing', 0.7292521852020617),
#  ('march', 0.72754860727727766),
#  ('society', 0.72735125833080938),
#  ('donald', 0.72731607617519511),
#  ('greatly', 0.72572335099455798),
#  ('delivers', 0.72417928980767377),
#  ('best', 0.72378860922586374),
#  ('magic', 0.72312801277188121),
#  ('jim', 0.7220151645607974),
#  ('brad', 0.72180243632032148),
#  ('ken', 0.7216623508679666),
#  ('sophisticated', 0.72033332086410207),
#  ('effectively', 0.71995843801060211),
#  ('relationships', 0.71955594253324229),
#  ('simon', 0.71711146099867396),
#  ('andrew', 0.71699839638212515),
#  ('influence', 0.71690126656805242),
#  ('charlie', 0.71484991700543965),
#  ('emotionally', 0.71393795022901896),
#  ('identity', 0.71271727675404262),
#  ('india', 0.71261928397276564),
#  ('dan', 0.71226822200672368),
#  ('genius', 0.71084675765934613),
#  ('affected', 0.71084675765934613),
#  ('beatty', 0.71084675765934613),
#  ('atmosphere', 0.71019498517728041),
#  ('roy', 0.7085152107882593),
#  ('britain', 0.70657020089208611),
#  ('patient', 0.70580557743186878),
#  ('stylish', 0.70580557743186878),
#  ('bitter', 0.70534245365376347),
#  ('wave', 0.70470800296102132),
#  ('sky', 0.70405921401092786),
#  ('surprisingly', 0.70388842239135796),
#  ('cowboy', 0.70258121279330399),
#  ('match', 0.69904193447129437),
#  ('romantic', 0.69899173255622848),
#  ('directs', 0.69798980503573327),
#  ('rebel', 0.69798980503573327),
#  ('wells', 0.69727089774380746),
#  ('dawson', 0.69698595686711096),
#  ('complaint', 0.6967378486906739),
#  ('refuses', 0.69638867448411634),
#  ('meets', 0.69610139245737668),
#  ('brooks', 0.69610139245737668),
#  ('patrick', 0.69538682315345002),
#  ('andy', 0.69471335159269021),
#  ('love', 0.69229502882537908),
#  ('paul', 0.69203297431654187),
#  ('luke', 0.68927870378202494),
#  ('france', 0.68888278177348772),
#  ('unlike', 0.68887184270954338),
#  ('sports', 0.68877080596014639),
#  ('handsome', 0.68877080596014639),
#  ('performance', 0.68866209455258898),
#  ('greater', 0.68741650585096037),
#  ('award', 0.68719123680709393),
#  ('ride', 0.68710486610398269),
#  ('interpretation', 0.68699331498556704),
#  ('brando', 0.68687756754634999),
#  ('noble', 0.68663249953875172),
#  ('le', 0.68559997492456237),
#  ('sunshine', 0.68463649089203671),
#  ('relations', 0.68339100561458066),
#  ('dreams', 0.6805395637053705),
#  ('paced', 0.67976905461376924),
#  ('rings', 0.67968802718594046),
#  ('effective', 0.6795150317698877),
#  ('succeeds', 0.67824377505737043),
#  ('h', 0.67739882359180614),
#  ('glimpse', 0.67645230198777528),
#  ('aired', 0.67611099340737746),
#  ('works', 0.6759994493991669),
#  ('imaginative', 0.67538472422010487),
#  ('tricks', 0.67499786205426793),
#  ('striking', 0.67499786205426793),
#  ('carefully', 0.67459377266419751),
#  ('master', 0.67449606393384476),
#  ('easy', 0.67141394390750819),
#  ('demands', 0.67116827384117006),
#  ('complicated', 0.6707998818679487),
#  ('england', 0.67030768859012257),
#  ('city', 0.66985161795642323),
#  ('instant', 0.66927969915330188),
#  ('lion', 0.66919393953745243),
#  ('ruthless', 0.66857591982943998),
#  ('saga', 0.66857591982943998),
#  ('trilogy', 0.66782937257565544),
#  ('perspective', 0.66697746282656056),
#  ('sees', 0.66628127572154427),
#  ('appreciate', 0.66469994598474702),
#  ('victor', 0.66367136242699176),
#  ('definitely', 0.66323782060230851),
#  ('both', 0.66305874168279888),
#  ('douglas', 0.66159882282501936),
#  ('distant', 0.66114444947377149),
#  ('accomplished', 0.66114444947377149),
#  ('future', 0.66052056531014802),
#  ('manhattan', 0.66035735773695448),
#  ('inspired', 0.66021650274693355),
#  ('workers', 0.66006145597417987),
#  ('pushing', 0.65953056976096036),
#  ('marriage', 0.65859937310605643),
#  ('joseph', 0.6567795363890705),
#  ('eccentric', 0.6567795363890705),
#  ('page', 0.65622382645534749),
#  ('divorce', 0.65575964848832502),
#  ('colonel', 0.65575964848832502),
#  ('joan', 0.65534481591341009),
#  ('hudson', 0.6544780394007913),
#  ('shaw', 0.65353804246489944),
#  ('era', 0.65272130408804663),
#  ('father', 0.65264064797895582),
#  ('brave', 0.6514233371885455),
#  ('meeting', 0.65130007062444484),
#  ('individual', 0.65130007062444484),
#  ('pleasant', 0.65076795759108386),
#  ('fantasy', 0.65026158902185638),
#  ('seeking', 0.6500635944236336),
#  ('friendly', 0.6494945504022086),
#  ('progress', 0.64777857553009432),
#  ('personal', 0.64662716492505246),
#  ('awards', 0.64662716492505246),
#  ('larger', 0.64469479717399858),
#  ('concert', 0.64469479717399858),
#  ('william', 0.64407288511995575),
#  ('ted', 0.64313675998528386),
#  ('keeping', 0.64111750911408283),
#  ('jack', 0.64047514612219447),
#  ('nation', 0.63994314449648071),
#  ('griffith', 0.63986581394700859),
#  ('albeit', 0.63959107609098309),
#  ('adapted', 0.63855899027554219),
#  ('jane', 0.63736783951225573),
#  ('emily', 0.63645183688340001),
#  ('gives', 0.63505519394123999),
#  ('animation', 0.63441250624217438),
#  ('mouse', 0.63430668053701189),
#  ('discovers', 0.63339717615417124),
#  ('profound', 0.63273805276438533),
#  ('recognized', 0.63199275740661476),
#  ('segment', 0.63087025103843075),
#  ('morgan', 0.63000628368901213),
#  ('ultimate', 0.62938056220095606),
#  ('drew', 0.62860865942237409),
#  ('contract', 0.62860865942237409),
#  ('criticism', 0.62750307611462453),
#  ('artist', 0.62745192129455041),
#  ('sexuality', 0.62733396199037361),
#  ('families', 0.62700737805540041),
#  ('classic', 0.62609504268205818),
#  ('impressive', 0.62592820596989451),
#  ('moved', 0.62563688903321657),
#  ('versions', 0.62482793658246816),
#  ('peoples', 0.62482793658246816),
#  ('determined', 0.62394664631656283),
#  ('innocent', 0.62308886619877635),
#  ('eddie', 0.62305480373957689),
#  ('fashioned', 0.62168821657780038),
#  ('remembered', 0.62045744719166762),
#  ('tap', 0.62030985660767901),
#  ('charismatic', 0.62012204554505546),
#  ('brian', 0.61883128658407915),
#  ('washington', 0.61877021042208624),
#  ('nature', 0.61862611328519868),
#  ('trio', 0.61838710535083607),
#  ('pleasure', 0.61809201439744799),
#  ('offers', 0.61755882323578926),
#  ('melodrama', 0.6174918193160347),
#  ('shine', 0.61636003734617506),
#  ('brady', 0.61636003734617506),
#  ('rough', 0.61628817503433353),
#  ('games', 0.61624200378516225),
#  ('images', 0.61562146389556294),
#  ('academy', 0.615099287032842),
#  ('ward', 0.61498240771060908),
#  ('satisfied', 0.61421992197027453),
#  ('dealing', 0.61222069023940107),
#  ('figures', 0.61062615687194188),
#  ('russell', 0.61025952075417755),
#  ('fine', 0.60639513967135406),
#  ('bound', 0.60517840761398811),
#  ('cook', 0.60344256197467194),
#  ('river', 0.60287315793549912),
#  ('brown', 0.60266959559382927),
#  ('claire', 0.60217540235421851),
#  ('hall', 0.60187140478385803),
#  ('morality', 0.60052569067954875),
#  ('falk', 0.60052569067954875),
#  ('job', 0.59928104432785412),
#  ('believable', 0.59829924529120604),
#  ('broadway', 0.5980300323168799),
#  ('stood', 0.59713252732035671),
#  ('peace', 0.59533387053750197),
#  ('always', 0.59528597896401514),
#  ('anna', 0.59522164338963712),
#  ('kubrick', 0.59495515438073154),
#  ('visually', 0.59258859489752624),
#  ('experiences', 0.59244867800793033),
#  ('expressions', 0.59179468629965781),
#  ('struggles', 0.59179468629965781),
#  ('timing', 0.5914631396314276),
#  ('growing', 0.59091655791104669),
#  ('clint', 0.59060754124376036),
#  ('helen', 0.58982956653191931),
#  ('authentic', 0.58965757283793074),
#  ('quirky', 0.58600254310861766),
#  ('touch', 0.58515854249584942),
#  ('timothy', 0.58515854249584942),
#  ('streep', 0.58480603676398124),
#  ('mexico', 0.58443095705514669),
#  ('personalities', 0.58383409058629565),
#  ('inner', 0.58335206783425331),
#  ('pre', 0.58287265009969003),
#  ('lives', 0.58243189976445897),
#  ('sisters', 0.58178964542974476),
#  ('overcome', 0.58174435044615636),
#  ('civil', 0.5811421221834504),
#  ('australia', 0.58040655760449655),
#  ('tales', 0.58026783248809166),
#  ('surprises', 0.58018206551689966),
#  ('adventures', 0.58018206551689966),
#  ('countries', 0.57957306636473016),
#  ('realism', 0.57888782975998898),
#  ('tradition', 0.57821721388596836),
#  ('wealth', 0.57642290625180392),
#  ('overwhelming', 0.57642290625180392),
#  ('odds', 0.57642290625180392),
#  ('young', 0.57582266830814688),
#  ('oliver', 0.5751015053748032),
#  ('rogers', 0.57502441328826781),
#  ('french', 0.57441117045179046),
#  ('performing', 0.57360202991016263),
#  ('suspenseful', 0.57325856433920919),
#  ('variety', 0.57325856433920919),
#  ('survival', 0.57318786548096634),
#  ('understanding', 0.57200279720085712),
#  ('players', 0.57152614403033875),
#  ('reminiscent', 0.57008708780271811),
#  ('branagh', 0.56946808437843432),
#  ('war', 0.56933204949283389),
#  ('knowing', 0.56901656222012853),
#  ('kirk', 0.568790164211464),
#  ('jr', 0.56828886918885146),
#  ('psychological', 0.5679840376059393),
#  ('grand', 0.56558595492192654),
#  ('howard', 0.56515317938141529),
#  ('mainstream', 0.5647971466774202),
#  ('grow', 0.56428869363481504),
#  ('sent', 0.56425616749192498),
#  ('generation', 0.56407013828480301),
#  ('true', 0.56360265342358629),
#  ('brothers', 0.56220128708402717),
#  ('disc', 0.56181117849885831),
#  ('bug', 0.56181117849885831),
#  ('dick', 0.56050270595365059),
#  ('gangster', 0.5591108649254527),
#  ('tend', 0.55900770035207559),
#  ('sutherland', 0.55879912802886678),
#  ('david', 0.55872013180747826),
#  ('tribute', 0.55866926633139191),
#  ('sacrifice', 0.55858751020985675),
#  ('jeff', 0.55787210833059586),
#  ('charm', 0.55736606820140722),
#  ('twists', 0.55662266986729081),
#  ('hearts', 0.55574731115750231),
#  ('greek', 0.55499684207912814),
#  ('hamilton', 0.55499684207912814),
#  ('describes', 0.55450068726865231),
#  ('thanks', 0.5543518888158816),
#  ('europe', 0.55359530015383973),
#  ('redemption', 0.55322598983665172),
#  ('pulls', 0.55251852606466101),
#  ('documentaries', 0.55206858230003986),
#  ('jealous', 0.55206858230003986),
#  ('family', 0.55173192119805003),
#  ('madness', 0.55155772660566027),
#  ('mountains', 0.55131698512072758),
#  ('trial', 0.55097269177940267),
#  ('brilliance', 0.54950447833110205),
#  ('superior', 0.54914887219670505),
#  ('color', 0.54856595174883771),
#  ('providing', 0.54856595174883771),
#  ('explore', 0.54856595174883771),
#  ('shorts', 0.54815687013135128),
#  ('world', 0.54791695569126564),
#  ('faithful', 0.54788544814993301),
#  ('jackson', 0.54767189715195697),
#  ('olivier', 0.54743536937855164),
#  ('roman', 0.54743536937855164),
#  ('dealt', 0.54724057050776909),
#  ('life', 0.54722953041250877),
#  ('york', 0.54542200125886986),
#  ('heroic', 0.54488464335790954),
#  ('received', 0.54417338891222078),
#  ('stands', 0.54354196310436165),
#  ('ironically', 0.54266622962164945),
#  ('temple', 0.54266622962164945),
#  ('enjoy', 0.54224285144239448),
#  ('gift', 0.54071915404413329),
#  ('revolution', 0.54019770207832107),
#  ('each', 0.53952249355624582),
#  ('share', 0.5389965007326869),
#  ('different', 0.53785733220243215),
#  ('union', 0.53723438573928772),
#  ('fellow', 0.53717445346274229),
#  ('jazz', 0.53692824766862801),
#  ('julie', 0.53640246555564042),
#  ('loves', 0.53508260141155073),
#  ('century', 0.53343498907154085),
#  ('series', 0.53310848795600074),
#  ('approach', 0.53291005467628472),
#  ('pays', 0.53262028359341096),
#  ('musical', 0.53148194869165144),
#  ('moves', 0.53132709799322342),
#  ('symbolism', 0.53109132122557379),
#  ('radio', 0.53025588092195253),
#  ('dennis', 0.53002783074992665),
#  ('ourselves', 0.52991928258157039),
#  ('wwii', 0.52894616487918555),
#  ('uncle', 0.52889200250036061),
#  ('performed', 0.52842681924299928),
#  ('demons', 0.52842681924299928),
#  ('countryside', 0.52806743020049673),
#  ('reminds', 0.52760253014563341),
#  ('appearances', 0.52756780490906419),
#  ('jeremy', 0.52756780490906419),
#  ('aging', 0.52682596511243185),
#  ('tells', 0.52618566706092751),
#  ('deep', 0.52584297083294373),
#  ('discovered', 0.52548278156596417),
#  ('eric', 0.52548278156596417),
#  ('arrives', 0.52508807068655494),
#  ('youth', 0.52505613557869157),
#  ('epic', 0.52481186574073058),
#  ('tarzan', 0.52427325917979317),
#  ('famous', 0.52350590894189974),
#  ('sympathetic', 0.52324814376454787),
#  ('loyal', 0.52324814376454787),
#  ('attitude', 0.52282876862734662),
#  ('adult', 0.5226642021421154),
#  ('carter', 0.52259046534557707),
#  ('lust', 0.52232944824747529),
#  ('passion', 0.52224058700424802),
#  ('desire', 0.52194009910453254),
#  ('com', 0.52142498920303271),
#  ('dirty', 0.5208812787542817),
#  ('fox', 0.5208812787542817),
#  ('horrors', 0.52084718222700965),
#  ('shows', 0.51992781558097967),
#  ('human', 0.519633306546886),
#  ('provided', 0.5194093674573822),
#  ('karloff', 0.5192239934648224),
#  ('atmospheric', 0.5192239934648224),
#  ('fits', 0.51909013361588419),
#  ('smile', 0.51879379341516751),
#  ('daily', 0.51840551928875989),
#  ('south', 0.51798331113387075),
#  ('visit', 0.51758240622887042),
#  ('proud', 0.5174387796577079),
#  ('duo', 0.51669074321838881),
#  ('cameron', 0.51669074321838881),
#  ('ring', 0.51653992502942936),
#  ('investigation', 0.51632770091997404),
#  ('shining', 0.51632770091997404),
#  ('present', 0.51630983436527067),
#  ('alan', 0.51588892572253742),
#  ('accurate', 0.51520473617535034),
#  ('japan', 0.51508483312538689),
#  ('fun', 0.51505228439722561),
#  ('hitchcock', 0.51422409772510236),
#  ('fu', 0.51335407011934941),
#  ('traveling', 0.51256324366453143),
#  ('begins', 0.51238864741790724),
#  ('individuals', 0.51223308353387043),
#  ('success', 0.5120406907441587),
#  ('finding', 0.51132177857646655),
#  ('recently', 0.5102119385672278),
#  ('contemporary', 0.5091435375830059),
#  ('frightening', 0.50900578704900468),
#  ('position', 0.50884346256199942),
#  ('stunts', 0.50827460197438534),
#  ('differences', 0.50774395722858268),
#  ('possibility', 0.50751436246233472),
#  ('genuine', 0.50735941578950439),
#  ('league', 0.50578782973603353),
#  ('helping', 0.50578782973603353),
#  ('answers', 0.50578782973603353),
#  ('among', 0.50560249391729695),
#  ('continues', 0.50538713313505224),
#  ('viewing', 0.50537988993370198),
#  ('appropriate', 0.50440505596306795),
#  ('battles', 0.50431094274479704),
#  ('finds', 0.50314696444346063),
#  ('hugh', 0.50292044425887739),
#  ('brutal', 0.50262885656181222),
#  ('honor', 0.50262885656181222),
#  ('desperation', 0.50231493409808203),
#  ('companion', 0.50231493409808203),
#  ('tracy', 0.50223266004315881),
#  ('depicted', 0.5015389381977865),
#  ('age', 0.50099051910749459),
#  ('plays', 0.50055760478569999),
#  ('brought', 0.50023077387779935),
#  ('combination', 0.50008108448301347),
#  ('james', 0.50002369073317698),
#  ('roles', 0.4999819518930933),
#  ('initially', 0.499874792579239),
#  ('guide', 0.49949405775644073),
#  ('thoroughly', 0.49917107077000833),
#  ('hilarious', 0.49895875698609138),
#  ('dance', 0.49818684815838665),
#  ('intrigue', 0.49783842823917956),
#  ('warming', 0.49783842823917956),
#  ('cuba', 0.49783842823917956),
#  ('planned', 0.49681488669639234),
#  ('fully', 0.49625720793770012),
#  ('julia', 0.49481020844401424),
#  ('san', 0.49481020844401424),
#  ('broadcast', 0.49375771525384266),
#  ('shakespeare', 0.49346511592473352),
#  ('singing', 0.49275797700676055),
#  ('romance', 0.49268743331079035),
#  ('strongly', 0.49247648509779424),
#  ('nonetheless', 0.49247648509779424),
#  ('official', 0.49247648509779424),
#  ('primary', 0.49247648509779424),
#  ('crime', 0.49208971270852081),
#  ('happy', 0.49171793237993766),
#  ('detail', 0.49119689439216907),
#  ('especially', 0.48970448055078364),
#  ('trade', 0.48934659208886655),
#  ('humanity', 0.48884671704721538),
#  ('nine', 0.48884671704721538),
#  ('necessary', 0.48841419108891532),
#  ('settings', 0.48743869106783694),
#  ('cup', 0.48659065292053283),
#  ('piano', 0.48659065292053283),
#  ('grey', 0.4850827360728559),
#  ('discovery', 0.48492927946241116),
#  ('vicious', 0.48492927946241116),
#  ('ordinary', 0.48375232943745583),
#  ('drama', 0.4834576088509549),
#  ('pictures', 0.48313814642638242),
#  ('mistaken', 0.48302334245403883),
#  ('sinister', 0.48262418865478252),
#  ('hatred', 0.4816264690737283),
#  ('reveal', 0.48088886992540625),
#  ('max', 0.47957308026188628),
#  ('bird', 0.47957308026188628),
#  ('machines', 0.47957308026188628),
#  ('history', 0.47863771399782379),
#  ('photographed', 0.47858737293712694),
#  ('spirit', 0.47797179889491243),
#  ('losing', 0.47787768567664146),
#  ('dated', 0.47771001498149318),
#  ('smaller', 0.47720901296700569),
#  ('crisis', 0.47712109701459954),
#  ('challenge', 0.47656102979189457),
#  ('soviet', 0.47641684408044882),
#  ('episode', 0.47634497040558871),
#  ('inevitable', 0.47578160652562412),
#  ('role', 0.47574793898584272),
#  ('familiar', 0.4756419849000022),
#  ('genuinely', 0.47561071747492417),
#  ('ways', 0.47539447788061195),
#  ('francisco', 0.4735185713531801),
#  ('techniques', 0.47318328216311528),
#  ('surfing', 0.47106239059397759),
#  ('spielberg', 0.4707056299765654),
#  ('cynical', 0.4707056299765654),
#  ('tour', 0.4707056299765654),
#  ('higher', 0.46925484598349448),
#  ('ryan', 0.46903791212577656),
#  ('dream', 0.46869729333168009),
#  ('critics', 0.468644009729696),
#  ('born', 0.46859814763700064),
#  ('defeat', 0.46798546508949834),
#  ('african', 0.46788273767659788),
#  ('detective', 0.46741569696970298),
#  ('warner', 0.46695019175884528),
#  ('remains', 0.46655280008800259),
#  ('deserved', 0.46591516415650303),
#  ('lynch', 0.46572429962636125),
#  ('information', 0.46548311783441726),
#  ('struggle', 0.46438099164475904),
#  ('breaking', 0.46345236575851378),
#  ('shadows', 0.46262352194811296),
#  ('language', 0.46226270650129747),
#  ('hidden', 0.46178353869838795),
#  ('visual', 0.46152462073862727),
#  ('social', 0.46015499440478469),
#  ('treasure', 0.45930834012898764),
#  ('closely', 0.45920938411485507),
#  ('segments', 0.45920938411485507),
#  ('reality', 0.45893562956958045),
#  ('presents', 0.45800244163604592),
#  ('mixed', 0.45795529072956109),
#  ('hamlet', 0.45734994347717611),
#  ('popular', 0.45722704266675385),
#  ('sometimes', 0.45704064918119008),
#  ('modern', 0.45685090515523236),
#  ('web', 0.45675840249571492),
#  ('chief', 0.45638519853542131),
#  ('represents', 0.45610884092691933),
#  ('follows', 0.45589596173505637),
#  ('surprised', 0.4555799782337876),
#  ('justice', 0.45552561006508241),
#  ('oz', 0.45506204924753652),
#  ('keeps', 0.45501892256289367),
#  ('caine', 0.45465535229893611),
#  ('restaurant', 0.45459779668580907),
#  ('john', 0.45286734700274828),
#  ('rap', 0.45261188653386641),
#  ('birth', 0.45238202789591597),
#  ('welcome', 0.45234869400701483),
#  ('lose', 0.45153386019749325),
#  ('searching', 0.45092748218492168),
#  ('chinese', 0.45013754815975693),
#  ('closer', 0.4500972621289327),
#  ('jon', 0.44991687067899816),
#  ('years', 0.44957082995808745),
#  ('controversial', 0.44942823152928046),
#  ('fame', 0.44926773076655735),
#  ('caught', 0.44917967934446995),
#  ('wallace', 0.4486372799733731),
#  ('visuals', 0.44858953474191898),
#  ('elizabeth', 0.44843114399160772),
#  ('thrilling', 0.44802472252696035),
#  ('bridge', 0.44802472252696035),
#  ('puts', 0.44727537816817936),
#  ('criminal', 0.44649650478602693),
#  ('marry', 0.44613614783909222),
#  ('ocean', 0.44595646946290124),
#  ('enormous', 0.44595646946290124),
#  ('revolutionary', 0.44595646946290124),
#  ('minor', 0.4451777455150322),
#  ('nazi', 0.44503070831435559),
#  ('learned', 0.44494391908195186),
#  ('flaws', 0.44450565731176456),
#  ('wayne', 0.44440808205677179),
#  ('michelle', 0.44430494142442833),
#  ('cary', 0.44407994423594388),
#  ('comedic', 0.44260465505762114),
#  ('de', 0.44216647495859235),
#  ('slowly', 0.44198032108326191),
#  ('liked', 0.44187287988483098),
#  ('physical', 0.44084294718981543),
#  ('glenn', 0.44080447455347332),
#  ('light', 0.44058649090138391),
#  ('johnny', 0.44027451277402563),
#  ('international', 0.44000543336034054),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.9651729200194987),
#  ('uwe', -4.6184154127381118),
#  ('seagal', -3.6397767411062043),
#  ('unwatchable', -3.2516656476911914),
#  ('stinker', -3.2020687065518194),
#  ('mst', -2.9463863994508359),
#  ('incoherent', -2.9318284715745109),
#  ('unfunny', -2.6895800190398091),
#  ('waste', -2.6188938868722635),
#  ('blah', -2.5667791841386127),
#  ('horrid', -2.478714679540079),
#  ('pointless', -2.453874540540272),
#  ('atrocious', -2.4222182679385904),
#  ('redeeming', -2.3660069194315416),
#  ('prom', -2.3545448319247568),
#  ('drivel', -2.3412228856994597),
#  ('lousy', -2.3042503723131071),
#  ('worst', -2.2867191512177283),
#  ('laughable', -2.2626307774870131),
#  ('awful', -2.2267662564366946),
#  ('poorly', -2.2197209484908624),
#  ('wasting', -2.1996906698314129),
#  ('remotely', -2.1933183223691541),
#  ('existent', -2.0748011621233338),
#  ('boredom', -1.9897527869194898),
#  ('miserably', -1.9863511186138239),
#  ('sucks', -1.9843764298831092),
#  ('lame', -1.9807460083977015),
#  ('uninspired', -1.9771626925594177),
#  ('insult', -1.9747930232040993)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.keys())

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i, word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'chronological': 1,
#  'atrophy': 2,
#  'torment': 3,
#  'yobs': 4,
#  'ullman': 5,
#  'lior': 6,
#  'haitians': 7,
#  'incl': 8,
#  'rarity': 9,
#  'widened': 10,
#  'meantime': 11,
#  'hesterical': 12,
#  'reviewer': 13,
#  'grays': 14,
#  'mimes': 15,
#  'nesson': 16,
#  'sirhan': 17,
#  'reverential': 18,
#  'trumpery': 19,
#  'humongous': 20,
#  'pablo': 21,
#  'guitry': 22,
#  'stallyns': 23,
#  'unicorns': 24,
#  'lowcut': 25,
#  'frocked': 26,
#  'aloofness': 27,
#  'amaturish': 28,
#  'aran': 29,
#  'micmac': 30,
#  'prepping': 31,
#  'grrrl': 32,
#  'bangers': 33,
#  'talker': 34,
#  'betray': 35,
#  'showpiece': 36,
#  'shoebat': 37,
#  'zips': 38,
#  'delineated': 39,
#  'unofficially': 40,
#  'housekeeping': 41,
#  'kellie': 42,
#  'unnameable': 43,
#  'grumpy': 44,
#  'sevier': 45,
#  'invalid': 46,
#  'immaturely': 47,
#  'quiche': 48,
#  'felsh': 49,
#  'delouise': 50,
#  'decodes': 51,
#  'roughnecks': 52,
#  'construction': 53,
#  'startrek': 54,
#  'immaterial': 55,
#  'trumpet': 56,
#  'goodmans': 57,
#  'spiffing': 58,
#  'lodi': 59,
#  'unwinding': 60,
#  'castings': 61,
#  'burddo': 62,
#  'lemon': 63,
#  'epitomized': 64,
#  'rajinikanth': 65,
#  'sympathetic': 66,
#  'exp': 67,
#  'caricaturist': 68,
#  'poundage': 69,
#  'lobotomized': 70,
#  'pernell': 71,
#  'marathi': 72,
#  'motions': 73,
#  'forsaking': 74,
#  'filmakers': 75,
#  'spoilers': 76,
#  'twirls': 77,
#  'whispery': 78,
#  'crisping': 79,
#  'restroom': 80,
#  'arvidson': 81,
#  'omaha': 82,
#  'bloodstorm': 83,
#  'entrapement': 84,
#  'good': 85,
#  'roby': 86,
#  'munk': 87,
#  'jinx': 88,
#  'mashall': 89,
#  'genuises': 90,
#  'chemistry': 91,
#  'buckle': 92,
#  'lvaro': 93,
#  'crowding': 94,
#  'effectually': 95,
#  'bocka': 96,
#  'lamas': 97,
#  'dwell': 98,
#  'apathy': 99,
#  'morales': 100,
#  'baught': 101,
#  'ealings': 102,
#  'ranchers': 103,
#  'uden': 104,
#  'yawning': 105,
#  'dourif': 106,
#  'adjusts': 107,
#  'anchorman': 108,
#  'libertine': 109,
#  'eu': 110,
#  'gifters': 111,
#  'mat': 112,
#  'sleaze': 113,
#  'alisha': 114,
#  'mondays': 115,
#  'corrina': 116,
#  'duetting': 117,
#  'mekum': 118,
#  'ostrich': 119,
#  'nacho': 120,
#  'constipated': 121,
#  'ire': 122,
#  'cinemaphotography': 123,
#  'computing': 124,
#  'whitfield': 125,
#  'buffed': 126,
#  'boll': 127,
#  'trickery': 128,
#  'resnikoff': 129,
#  'gideon': 130,
#  'tuba': 131,
#  'midts': 132,
#  'gf': 133,
#  'shoppingmal': 134,
#  'pare': 135,
#  'catweazle': 136,
#  'frog': 137,
#  'singer': 138,
#  'thyself': 139,
#  'vamps': 140,
#  'obligingly': 141,
#  'capulets': 142,
#  'hillsides': 143,
#  'anjane': 144,
#  'begetting': 145,
#  'squads': 146,
#  'jellybeans': 147,
#  'loc': 148,
#  'dipaolo': 149,
#  'nogami': 150,
#  'siam': 151,
#  'introductions': 152,
#  'irreverently': 153,
#  'vntoarea': 154,
#  'coutard': 155,
#  'statham': 156,
#  'polarised': 157,
#  'truehart': 158,
#  'molder': 159,
#  'jymn': 160,
#  'distrusting': 161,
#  'seek': 162,
#  'politicians': 163,
#  'eurovision': 164,
#  'biographic': 165,
#  'blaylock': 166,
#  'bungles': 167,
#  'erk': 168,
#  'nous': 169,
#  'myrnah': 170,
#  'overlays': 171,
#  'hidebound': 172,
#  'entrancing': 173,
#  'tori': 174,
#  'sentry': 175,
#  'mccullough': 176,
#  'libels': 177,
#  'ixpe': 178,
#  'plonking': 179,
#  'bloodwork': 180,
#  'seducer': 181,
#  'pino': 182,
#  'clash': 183,
#  'british': 184,
#  'dudettes': 185,
#  'purses': 186,
#  'sandburg': 187,
#  'horseplay': 188,
#  'hiroshimas': 189,
#  'drusilla': 190,
#  'lieutenent': 191,
#  'lowitz': 192,
#  'immersion': 193,
#  'eminent': 194,
#  'longoria': 195,
#  'bookish': 196,
#  'unsupportive': 197,
#  'mindbender': 198,
#  'runaway': 199,
#  'filmatography': 200,
#  'eldest': 201,
#  'rookies': 202,
#  'geometric': 203,
#  'disdainful': 204,
#  'exciting': 205,
#  'royalist': 206,
#  'plasters': 207,
#  'lamp': 208,
#  'mendelito': 209,
#  'jox': 210,
#  'misusing': 211,
#  'elie': 212,
#  'celibate': 213,
#  'beheaded': 214,
#  'mnica': 215,
#  'coccio': 216,
#  'abundant': 217,
#  'riffles': 218,
#  'motel': 219,
#  'strum': 220,
#  'spicier': 221,
#  'entertaining': 222,
#  'volleyball': 223,
#  'cartwright': 224,
#  'illegitimate': 225,
#  'sneer': 226,
#  'shakycam': 227,
#  'sighing': 228,
#  'stiers': 229,
#  'laural': 230,
#  'elinore': 231,
#  'gaddis': 232,
#  'repertoire': 233,
#  'marnie': 234,
#  'warlocks': 235,
#  'absolutelly': 236,
#  'fintasy': 237,
#  'capiche': 238,
#  'gauguin': 239,
#  'riffling': 240,
#  'mutha': 241,
#  'bedlam': 242,
#  'wladyslaw': 243,
#  'resurrects': 244,
#  'record': 245,
#  'sjoholm': 246,
#  'rockaroll': 247,
#  'progresses': 248,
#  'crimean': 249,
#  'nachle': 250,
#  'dingo': 251,
#  'cityscapes': 252,
#  'besco': 253,
#  'cicely': 254,
#  'nerae': 255,
#  'willowbrook': 256,
#  'happenstances': 257,
#  'standbys': 258,
#  'barrio': 259,
#  'hires': 260,
#  'affronting': 261,
#  'shootings': 262,
#  'thierry': 263,
#  'cheers': 264,
#  'deities': 265,
#  'politicized': 266,
#  'uuhhhhh': 267,
#  'reflex': 268,
#  'transamerica': 269,
#  'neeson': 270,
#  'ghostlike': 271,
#  'preview': 272,
#  'stickers': 273,
#  'macisaac': 274,
#  'cronkite': 275,
#  'polled': 276,
#  'fattened': 277,
#  'clamour': 278,
#  'hordern': 279,
#  'haggardly': 280,
#  'propping': 281,
#  'thimbles': 282,
#  'screwballs': 283,
#  'conveniences': 284,
#  'blas': 285,
#  'easting': 286,
#  'cullum': 287,
#  'chastened': 288,
#  'torv': 289,
#  'contrast': 290,
#  'plesiosaur': 291,
#  'obstructive': 292,
#  'idolatry': 293,
#  'lewinski': 294,
#  'shihito': 295,
#  'guillotine': 296,
#  'bollywood': 297,
#  'nimoy': 298,
#  'sagamore': 299,
#  'exports': 300,
#  'hindersome': 301,
#  'complied': 302,
#  'stamos': 303,
#  'weeding': 304,
#  'enabler': 305,
#  'bedroom': 306,
#  'fictionalizes': 307,
#  'rarer': 308,
#  'lumpens': 309,
#  'nacht': 310,
#  'mermaid': 311,
#  'batouch': 312,
#  'impacts': 313,
#  'sollett': 314,
#  'assessment': 315,
#  'steadying': 316,
#  'persue': 317,
#  'unlockables': 318,
#  'lounging': 319,
#  'foreseen': 320,
#  'hawki': 321,
#  'tonne': 322,
#  'disablement': 323,
#  'hippiest': 324,
#  'nastie': 325,
#  'tapdancing': 326,
#  'wahlberg': 327,
#  'gongs': 328,
#  'ironclad': 329,
#  'murmur': 330,
#  'fembot': 331,
#  'yamamura': 332,
#  'cultivation': 333,
#  'unexpecting': 334,
#  'crash': 335,
#  'disavowed': 336,
#  'competence': 337,
#  'philes': 338,
#  'lillies': 339,
#  'banderas': 340,
#  'chang': 341,
#  'disses': 342,
#  'caprino': 343,
#  'elegance': 344,
#  'purser': 345,
#  'dolores': 346,
#  'nea': 347,
#  'saharan': 348,
#  'rennaissance': 349,
#  'muddily': 350,
#  'sheffielders': 351,
#  'pessimistic': 352,
#  'marijuana': 353,
#  'atrociously': 354,
#  'shoals': 355,
#  'barcode': 356,
#  'dissolution': 357,
#  'blaznee': 358,
#  'grotesquery': 359,
#  'liberates': 360,
#  'destroyers': 361,
#  'entertained': 362,
#  'moralist': 363,
#  'replayable': 364,
#  'fetischist': 365,
#  'lawyer': 366,
#  'foreman': 367,
#  'lutte': 368,
#  'lenoire': 369,
#  'setna': 370,
#  'habilities': 371,
#  'setback': 372,
#  'thanksgivings': 373,
#  'mariner': 374,
#  'stationmaster': 375,
#  'swore': 376,
#  'duddley': 377,
#  'marciano': 378,
#  'wrede': 379,
#  'bujeau': 380,
#  'dissecting': 381,
#  'hussy': 382,
#  'rumah': 383,
#  'outflanking': 384,
#  'primo': 385,
#  'paintbrush': 386,
#  'halop': 387,
#  'barnyard': 388,
#  'wolfe': 389,
#  'homosexually': 390,
#  'redundant': 391,
#  'prinze': 392,
#  'firemen': 393,
#  'blower': 394,
#  'estimate': 395,
#  'littleoff': 396,
#  'synthetically': 397,
#  'lawler': 398,
#  'reenact': 399,
#  'compost': 400,
#  'kireihana': 401,
#  'beadle': 402,
#  'emmerich': 403,
#  'broaden': 404,
#  'bracco': 405,
#  'enid': 406,
#  'smelly': 407,
#  'legally': 408,
#  'margarita': 409,
#  'boitano': 410,
#  'abcd': 411,
#  'chintz': 412,
#  'mcafee': 413,
#  'upset': 414,
#  'haverty': 415,
#  'occur': 416,
#  'understandings': 417,
#  'ostensibly': 418,
#  'habitats': 419,
#  'ustr': 420,
#  'skirmisher': 421,
#  'schizophrenic': 422,
#  'romaro': 423,
#  'skeksis': 424,
#  'berseker': 425,
#  'misrepresentative': 426,
#  'nombre': 427,
#  'pressure': 428,
#  'spirits': 429,
#  'quixote': 430,
#  'solidly': 431,
#  'tailoring': 432,
#  'rubens': 433,
#  'disregarding': 434,
#  'guilty': 435,
#  'waterworld': 436,
#  'occhi': 437,
#  'herding': 438,
#  'bracing': 439,
#  'corine': 440,
#  'kit': 441,
#  'lends': 442,
#  'scariest': 443,
#  'doh': 444,
#  'masumura': 445,
#  'enachanted': 446,
#  'hazmat': 447,
#  'kurylenko': 448,
#  'tannen': 449,
#  'inactivity': 450,
#  'konchalovksy': 451,
#  'buzzell': 452,
#  'granny': 453,
#  'hd': 454,
#  'impairs': 455,
#  'predating': 456,
#  'skimpole': 457,
#  'legal': 458,
#  'trustee': 459,
#  'madden': 460,
#  'misjudging': 461,
#  'omc': 462,
#  'discoverer': 463,
#  'sunny': 464,
#  'financier': 465,
#  'hillard': 466,
#  'deux': 467,
#  'vhala': 468,
#  'labyrinthian': 469,
#  'discover': 470,
#  'wrongfully': 471,
#  'denotes': 472,
#  'purr': 473,
#  'magnification': 474,
#  'camarary': 475,
#  'sleazebags': 476,
#  'adulteries': 477,
#  'glamourise': 478,
#  'contributors': 479,
#  'gigolo': 480,
#  'rajiv': 481,
#  'voyage': 482,
#  'boeing': 483,
#  'sightas': 484,
#  'sonnie': 485,
#  'nyqvist': 486,
#  'hars': 487,
#  'provoke': 488,
#  'firmness': 489,
#  'smallville': 490,
#  'rmember': 491,
#  'amplifies': 492,
#  'grandiosely': 493,
#  'inlay': 494,
#  'ponderance': 495,
#  'togar': 496,
#  'awesomenes': 497,
#  'charecter': 498,
#  'friggen': 499,
#  'volney': 500,
#  'bearing': 501,
#  'intruder': 502,
#  'renews': 503,
#  'bacchus': 504,
#  'smilodons': 505,
#  'characterises': 506,
#  'gussied': 507,
#  'dummy': 508,
#  'murkier': 509,
#  'niagara': 510,
#  'bixby': 511,
#  'sacchi': 512,
#  'queues': 513,
#  'iceholes': 514,
#  'nurtured': 515,
#  'refuse': 516,
#  'megyn': 517,
#  'pleasure': 518,
#  'kai': 519,
#  'showboating': 520,
#  'horton': 521,
#  'beaded': 522,
#  'bogdanovic': 523,
#  'clavier': 524,
#  'embroider': 525,
#  'rves': 526,
#  'wraparound': 527,
#  'larkin': 528,
#  'perimeters': 529,
#  'ewald': 530,
#  'socialites': 531,
#  'doubter': 532,
#  'gyllenhaal': 533,
#  'bully': 534,
#  'pocketing': 535,
#  'huckster': 536,
#  'stocked': 537,
#  'rebellions': 538,
#  'habits': 539,
#  'scurries': 540,
#  'vishal': 541,
#  'dignitary': 542,
#  'padm': 543,
#  'multitask': 544,
#  'devotee': 545,
#  'hokiest': 546,
#  'boxing': 547,
#  'corri': 548,
#  'colonist': 549,
#  'boyce': 550,
#  'smack': 551,
#  'hsd': 552,
#  'quicksilver': 553,
#  'trintignant': 554,
#  'megabomb': 555,
#  'nabors': 556,
#  'grandly': 557,
#  'poms': 558,
#  'satrapi': 559,
#  'reccomend': 560,
#  'blues': 561,
#  'disgraced': 562,
#  'restores': 563,
#  'castel': 564,
#  'arent': 565,
#  'dreaful': 566,
#  'cyclical': 567,
#  'lorna': 568,
#  'hotd': 569,
#  'mcgonagle': 570,
#  'hairdo': 571,
#  'emanating': 572,
#  'idols': 573,
#  'schindlers': 574,
#  'timebomb': 575,
#  'grasses': 576,
#  'boat': 577,
#  'grudges': 578,
#  'alselmo': 579,
#  'glandular': 580,
#  'shadier': 581,
#  'sapphire': 582,
#  'wangles': 583,
#  'sulphuric': 584,
#  'geoeffry': 585,
#  'drawl': 586,
#  'blindfolded': 587,
#  'almodovar': 588,
#  'interval': 589,
#  'hubbie': 590,
#  'unmanaged': 591,
#  'grifasi': 592,
#  'cline': 593,
#  'whet': 594,
#  'exhude': 595,
#  'nurses': 596,
#  'kickboxing': 597,
#  'instinctual': 598,
#  'prosecuting': 599,
#  'retirony': 600,
#  'algy': 601,
#  'michiko': 602,
#  'ephron': 603,
#  'attractions': 604,
#  'illogically': 605,
#  'penitentiary': 606,
#  'kovacs': 607,
#  'ngela': 608,
#  'dockside': 609,
#  'phelps': 610,
#  'insaults': 611,
#  'glib': 612,
#  'difficulty': 613,
#  'accuracy': 614,
#  'myeres': 615,
#  'greenlight': 616,
#  'keisha': 617,
#  'oakley': 618,
#  'balcans': 619,
#  'realises': 620,
#  'vicarious': 621,
#  'razzie': 622,
#  'definetly': 623,
#  'schoolgirls': 624,
#  'disobeys': 625,
#  'falvia': 626,
#  'prawns': 627,
#  'madcat': 628,
#  'tolokonnikov': 629,
#  'pocasni': 630,
#  'seventeen': 631,
#  'mathau': 632,
#  'sodas': 633,
#  'ismir': 634,
#  'engrossing': 635,
#  'indefatigable': 636,
#  'illustrated': 637,
#  'kabul': 638,
#  'foresees': 639,
#  'coscarelli': 640,
#  'incorrectly': 641,
#  'permit': 642,
#  'eccentrics': 643,
#  'promising': 644,
#  'snitch': 645,
#  'poofs': 646,
#  'citing': 647,
#  'beart': 648,
#  'defendant': 649,
#  'poodles': 650,
#  'meyer': 651,
#  'responsibly': 652,
#  'taviani': 653,
#  'gordano': 654,
#  'chomet': 655,
#  'freelancer': 656,
#  'metcalfe': 657,
#  'dualities': 658,
#  'constellation': 659,
#  'retreads': 660,
#  'cinmea': 661,
#  'ocarina': 662,
#  'ayat': 663,
#  'afflect': 664,
#  'resituation': 665,
#  'safar': 666,
#  'semple': 667,
#  'marshall': 668,
#  'rakeesha': 669,
#  'differentiating': 670,
#  'conceit': 671,
#  'profusely': 672,
#  'gitwisters': 673,
#  'shortening': 674,
#  'crevice': 675,
#  'bankrolls': 676,
#  'sidearm': 677,
#  'edginess': 678,
#  'frontbenchers': 679,
#  'perishing': 680,
#  'designed': 681,
#  'blogg': 682,
#  'lomena': 683,
#  'subgenre': 684,
#  'catwomanly': 685,
#  'misapplication': 686,
#  'blissfully': 687,
#  'polyamorous': 688,
#  'diminutive': 689,
#  'bolivarians': 690,
#  'botticelli': 691,
#  'graffiti': 692,
#  'ritualistic': 693,
#  'nyaako': 694,
#  'bux': 695,
#  'usurer': 696,
#  'certification': 697,
#  'exclusively': 698,
#  'fetishes': 699,
#  'ambassadors': 700,
#  'spetters': 701,
#  'provence': 702,
#  'contradicted': 703,
#  'tau': 704,
#  'burrough': 705,
#  'zaping': 706,
#  'katsuya': 707,
#  'pointing': 708,
#  'boricuas': 709,
#  'pryors': 710,
#  'neal': 711,
#  'leticia': 712,
#  'passe': 713,
#  'tugging': 714,
#  'brace': 715,
#  'preferring': 716,
#  'adios': 717,
#  'christianty': 718,
#  'bloodstained': 719,
#  'yorkshire': 720,
#  'farfella': 721,
#  'augured': 722,
#  'kmadden': 723,
#  'zaire': 724,
#  'praiseworthiness': 725,
#  'sponsored': 726,
#  'langoliers': 727,
#  'mcg': 728,
#  'embers': 729,
#  'theme': 730,
#  'cups': 731,
#  'renaissance': 732,
#  'jardyce': 733,
#  'gooped': 734,
#  'lioness': 735,
#  'panchamda': 736,
#  'detaildetailfocus': 737,
#  'hault': 738,
#  'strengthening': 739,
#  'bluntly': 740,
#  'tot': 741,
#  'honking': 742,
#  'beginning': 743,
#  'urine': 744,
#  'seymour': 745,
#  'aortic': 746,
#  'processes': 747,
#  'dolman': 748,
#  'worshipers': 749,
#  'conanesque': 750,
#  'pensively': 751,
#  'inhaled': 752,
#  'torched': 753,
#  'prophesied': 754,
#  'flippin': 755,
#  'repaid': 756,
#  'zipper': 757,
#  'chetniks': 758,
#  'joycey': 759,
#  'osamu': 760,
#  'naish': 761,
#  'unromantic': 762,
#  'robed': 763,
#  'fireplace': 764,
#  'toola': 765,
#  'wertmueller': 766,
#  'vgen': 767,
#  'kara': 768,
#  'interrogator': 769,
#  'microwaved': 770,
#  'terrore': 771,
#  'text': 772,
#  'aetheist': 773,
#  'leveled': 774,
#  'stumbled': 775,
#  'granter': 776,
#  'desaturate': 777,
#  'patches': 778,
#  'ramo': 779,
#  'recycling': 780,
#  'hedron': 781,
#  'planetoids': 782,
#  'popularised': 783,
#  'embed': 784,
#  'recruitment': 785,
#  'vileness': 786,
#  'aside': 787,
#  'step': 788,
#  'scrooged': 789,
#  'inflected': 790,
#  'drablow': 791,
#  'silsby': 792,
#  'getty': 793,
#  'interspecies': 794,
#  'stinkbombs': 795,
#  'freinken': 796,
#  'contestent': 797,
#  'nris': 798,
#  'flys': 799,
#  'cellach': 800,
#  'myself': 801,
#  'narrowed': 802,
#  'our': 803,
#  'preservation': 804,
#  'cus': 805,
#  'parlance': 806,
#  'barks': 807,
#  'usa': 808,
#  'lyin': 809,
#  'reflectors': 810,
#  'artistical': 811,
#  'chalo': 812,
#  'grasping': 813,
#  'levieva': 814,
#  'sinker': 815,
#  'longendecker': 816,
#  'desis': 817,
#  'avoided': 818,
#  'likely': 819,
#  'maury': 820,
#  'sholay': 821,
#  'dominance': 822,
#  'electrics': 823,
#  'involution': 824,
#  'stratton': 825,
#  'liqueur': 826,
#  'whiffs': 827,
#  'archtypes': 828,
#  'blueray': 829,
#  'frames': 830,
#  'saddened': 831,
#  'shield': 832,
#  'explained': 833,
#  'gradef': 834,
#  'bullbeep': 835,
#  'panthers': 836,
#  'relive': 837,
#  'overtime': 838,
#  'sine': 839,
#  'oxbow': 840,
#  'thet': 841,
#  'deamon': 842,
#  'superlguing': 843,
#  'fannish': 844,
#  'pengy': 845,
#  'cathie': 846,
#  'armpitted': 847,
#  'fisticuff': 848,
#  'mres': 849,
#  'jie': 850,
#  'comprises': 851,
#  'saucy': 852,
#  'flirtations': 853,
#  'disengorges': 854,
#  'gravest': 855,
#  'bragg': 856,
#  'capitalist': 857,
#  'bucatinsky': 858,
#  'intertitle': 859,
#  'anatomically': 860,
#  'autocracy': 861,
#  'ministro': 862,
#  'humdrum': 863,
#  'muertos': 864,
#  'therefor': 865,
#  'darkens': 866,
#  'jannuci': 867,
#  'goldsboro': 868,
#  'jehovahs': 869,
#  'drags': 870,
#  'magaret': 871,
#  'rpond': 872,
#  'forthegill': 873,
#  'inarticulate': 874,
#  'gerri': 875,
#  'avarice': 876,
#  'koma': 877,
#  'literati': 878,
#  'priestly': 879,
#  'reductive': 880,
#  'lifes': 881,
#  'muder': 882,
#  'battleship': 883,
#  'frankly': 884,
#  'christien': 885,
#  'maddern': 886,
#  'bouncing': 887,
#  'futz': 888,
#  'dimestore': 889,
#  'pharmacy': 890,
#  'peeved': 891,
#  'unacceptably': 892,
#  'jayant': 893,
#  'jew': 894,
#  'zivagho': 895,
#  'withdraw': 896,
#  'ballyhooed': 897,
#  'entail': 898,
#  'negotiatior': 899,
#  'honky': 900,
#  'commercialized': 901,
#  'embarkation': 902,
#  'pedestrians': 903,
#  'wiseman': 904,
#  'illness': 905,
#  'parodied': 906,
#  'shiniest': 907,
#  'knitted': 908,
#  'ailton': 909,
#  'onomatopoeic': 910,
#  'grazzo': 911,
#  'disquieting': 912,
#  'nerve': 913,
#  'partaking': 914,
#  'lansing': 915,
#  'reluctantpopstar': 916,
#  'unhooking': 917,
#  'dalla': 918,
#  'dorthy': 919,
#  'honkytonks': 920,
#  'zaljko': 921,
#  'r': 922,
#  'tortoni': 923,
#  'unassaulted': 924,
#  'palagi': 925,
#  'amman': 926,
#  'delventhal': 927,
#  'disadvantaged': 928,
#  'magnificient': 929,
#  'thigns': 930,
#  'doubled': 931,
#  'tsu': 932,
#  'ablaze': 933,
#  'baddies': 934,
#  'mcphee': 935,
#  'breathes': 936,
#  'rivalries': 937,
#  'auburn': 938,
#  'confessions': 939,
#  'workin': 940,
#  'nanak': 941,
#  'bwainn': 942,
#  'struycken': 943,
#  'fallacy': 944,
#  'bizzzzare': 945,
#  'strongboy': 946,
#  'hock': 947,
#  'identifies': 948,
#  'leigh': 949,
#  'almost': 950,
#  'chomiak': 951,
#  'campaigning': 952,
#  'retool': 953,
#  'kibosh': 954,
#  'otomo': 955,
#  'orna': 956,
#  'europeans': 957,
#  'squeak': 958,
#  'funney': 959,
#  'dazzler': 960,
#  'expose': 961,
#  'sophisticate': 962,
#  'sneered': 963,
#  'photojournals': 964,
#  'hogan': 965,
#  'fed': 966,
#  'greenbush': 967,
#  'reinterpret': 968,
#  'males': 969,
#  'vp': 970,
#  'chalon': 971,
#  'geeeee': 972,
#  'facilty': 973,
#  'et': 974,
#  'merhi': 975,
#  'messinger': 976,
#  'enthuses': 977,
#  'compartment': 978,
#  'butterfly': 979,
#  'ramboesque': 980,
#  'lightly': 981,
#  'tele': 982,
#  'sled': 983,
#  'doberman': 984,
#  'phyillis': 985,
#  'moneymaker': 986,
#  'destinations': 987,
#  'matarazzo': 988,
#  'dalia': 989,
#  'bickle': 990,
#  'pacman': 991,
#  'appellation': 992,
#  'kimba': 993,
#  'colwell': 994,
#  'bribes': 995,
#  'dubbing': 996,
#  'chores': 997,
#  'bewareing': 998,
#  'wounds': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if label == "POSITIVE":
        return 1
    return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set(review.split(' ') for review in reveiws)
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        label_vocab = set(label for label in labels)
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {w: i for i, w in enumerate(self.review_vocab)}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {l: i for i, l in enumerate(self.label_vocab)}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = None
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = None
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"
        pass
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        pass
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        pass
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        pass

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        pass

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
